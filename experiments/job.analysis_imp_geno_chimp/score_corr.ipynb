# %%
import pandas as pd
import numpy as np
import scipy as sp
import time
import os
import ldspec
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
from statsmodels.stats.multitest import multipletests
import statsmodels.api as sm


# autoreload
# %load_ext autoreload
# %autoreload 2

# %%
# CHR_LIST = [22]
CHR_LIST = np.arange(1, 23)
DATA_PATH = '/n/groups/price/martin/LDSPEC_data/UKBimp_337K_MAF001_chimp'
SCORE_FILE_LIST = [
    DATA_PATH + '/ldspec_score_file/baseline.c@_score.tsv.gz',
    DATA_PATH + '/ldspec_score_file/pannot_prox_ld.c@_score.tsv.gz',
    DATA_PATH + '/ldspec_score_file/pannot_gene_ld.c@_score.tsv.gz',
    DATA_PATH + '/ldspec_score_file/pannot_baseline_0_100_ld.c@_score.tsv.gz',
    DATA_PATH + '/ldspec_score_file/pannot_baseline_0_1000_ld.c@_score.tsv.gz',
]

# %%
# Load --score_file
print("# Loading --score_file")
df_score = None
for score_file in SCORE_FILE_LIST:
    df_list = []
    for CHR in CHR_LIST:
        fpath = score_file.replace("@", "%d" % CHR)
        if os.path.exists(fpath):
            temp_df = pd.read_csv(fpath, sep="\t", index_col=None)
            col_list = [x for x in temp_df if x.startswith(("E", "LD", "DLD"))]
            temp_df[col_list] = temp_df[col_list].astype(np.float32)
            df_list.append(temp_df.copy())

    temp_df = pd.concat(df_list, axis=0)
    temp_df.index = temp_df["SNP"]
    if df_score is None:
        df_score = temp_df.copy()
    else:
        col_list = [x for x in temp_df if x not in df_score]
        df_score = df_score.join(temp_df[col_list])
    del temp_df

df_score = df_score.loc[df_score.isna().sum(axis=1) == 0].copy()
df_score.sort_values(["CHR", "BP"], inplace=True)
df_score.index = df_score["SNP"]
df_score.columns = [x.replace('DLD:', '').replace('LD:', '') for x in df_score]
n_snp = df_score.shape[0]
n_LD = len([x for x in df_score if x.startswith("AN:")])
n_DLD = len([x for x in df_score if x.startswith("pAN:")])
print("    Loaded: %d SNPs, %d LD scores, %d DLD scores" % (n_snp, n_LD, n_DLD))
# Out:
# # Loading --score_file
#     Loaded: 14820648 SNPs, 165 LD scores, 164 DLD scores

# %%
AN_list = [x for x in df_score if x.startswith('AN:')]
print('n_annot=%d' % len(AN_list))

with open(
    '/n/groups/price/martin/LDSPEC_data/UKBimp_337K_MAF001_chimp/'
    'ldspec_res_071623.prox_gene_fct_all_ld/blood_PLATELET_COUNT.pickle', 'br'
) as f:
    temp_df = pickle.load(f)
pAN_list = [x for x in df_score if x.startswith('pAN:')]
pAN_list = [x for x in pAN_list if x in temp_df['summary']['omega'].index]
print('n_pannot=%d' % len(pAN_list))
df_cor = df_score[AN_list + pAN_list].corr()
df_cor.to_csv('/n/groups/price/martin/LDSPEC_data/results/tables/score_corr.tsv', sep='\t')
# Out:
# n_annot=165
# n_pannot=136

# %% [markdown]
# ### Analysis

# %%
df_cor = pd.read_csv('/n/groups/price/martin/LDSPEC_data/results/tables/score_corr.tsv', 
                     sep='\t', index_col=0)

# %%
# AN vs. pAN
for AN in AN_list:
    for pAN in pAN_list:
        if df_cor.loc[AN, pAN] > 0.9:
                print('%-40s %-40s %0.3f' % (
                    AN.replace('AN:', ''), pAN.replace('pAN:', ''), df_cor.loc[AN, pAN]
                ))

# %%
# pAN vs. pAN
for mbin1,mbin2 in [['common', 'common'], ['lf', 'lf']]:
    print('%s %s' % (mbin1, mbin2))
    pAN_list1 = [x for x in pAN_list if mbin1 in x]
    pAN_list2 = [x for x in pAN_list if mbin2 in x]
    for i in range(len(pAN_list1)):
        start_ind = i+1 if mbin1==mbin2 else 0
        for j in range(start_ind, len(pAN_list2)):
            pAN_i,pAN_j = pAN_list1[i],pAN_list2[j]
            if np.absolute(df_cor.loc[pAN_i, pAN_j]) > 0.95:
                print('%-40s %-40s %0.5f' % (
                    pAN_i.replace('pAN:', ''), pAN_j.replace('pAN:', ''), df_cor.loc[pAN_i, pAN_j]
                ))

    print('')
# Out:
# common common
# proxy_0_100_ld_p0_p100_maf_common_block  proxy_100_1000_ld_p0_p100_maf_common_block 0.99877
# proxy_0_100_ld_p0_p100_maf_common_block  proxy_1000_10000_ld_p0_p100_maf_common_block 0.99575
# proxy_0_100_ld_p0_p100_maf_common_block  proxy_0_100_ld_n100_p0_maf_common_block  -0.98103
# proxy_0_100_ld_p0_p100_maf_common_block  proxy_100_1000_ld_n100_p0_maf_common_block -0.98400
# proxy_0_100_ld_p0_p100_maf_common_block  proxy_1000_10000_ld_n100_p0_maf_common_block -0.98273
# proxy_0_100_ld_p0_p100_maf_common_block  H3K4me1_Trynka_proxy_0_100_ld_p0_p100_maf_common_block 0.95096
# proxy_0_100_ld_p0_p100_maf_common_block  H3K4me3_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block 0.96173
# proxy_0_100_ld_p0_p100_maf_common_block  H3K4me3_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block -0.95456
# proxy_100_1000_ld_p0_p100_maf_common_block proxy_1000_10000_ld_p0_p100_maf_common_block 0.99682
# proxy_100_1000_ld_p0_p100_maf_common_block proxy_0_100_ld_n100_p0_maf_common_block  -0.98240
# proxy_100_1000_ld_p0_p100_maf_common_block proxy_100_1000_ld_n100_p0_maf_common_block -0.98595
# proxy_100_1000_ld_p0_p100_maf_common_block proxy_1000_10000_ld_n100_p0_maf_common_block -0.98468
# proxy_100_1000_ld_p0_p100_maf_common_block H3K4me1_Trynka_proxy_0_100_ld_p0_p100_maf_common_block 0.95077
# proxy_100_1000_ld_p0_p100_maf_common_block H3K4me3_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block 0.96174
# proxy_100_1000_ld_p0_p100_maf_common_block H3K4me3_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block -0.95468
# proxy_1000_10000_ld_p0_p100_maf_common_block proxy_0_100_ld_n100_p0_maf_common_block  -0.98294
# proxy_1000_10000_ld_p0_p100_maf_common_block proxy_100_1000_ld_n100_p0_maf_common_block -0.98660
# proxy_1000_10000_ld_p0_p100_maf_common_block proxy_1000_10000_ld_n100_p0_maf_common_block -0.98922
# proxy_1000_10000_ld_p0_p100_maf_common_block H3K4me3_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block 0.96122
# proxy_1000_10000_ld_p0_p100_maf_common_block H3K4me3_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block -0.95050
# proxy_0_100_ld_n100_p0_maf_common_block  proxy_100_1000_ld_n100_p0_maf_common_block 0.99835
# proxy_0_100_ld_n100_p0_maf_common_block  proxy_1000_10000_ld_n100_p0_maf_common_block 0.99524
# proxy_100_1000_ld_n100_p0_maf_common_block proxy_1000_10000_ld_n100_p0_maf_common_block 0.99762
# exon_ld_p0_p100_maf_common_block         exon_ld_n100_p0_maf_common_block         -0.96264
# exonic_gene_ld_p0_p100_maf_common_block  exonic_gene_ld_n100_p0_maf_common_block  -0.97736
# cS2G_promoter_ld_p0_p100_maf_common_block cS2G_promoter_ld_n100_p0_maf_common_block -0.98871
# cS2G_promoter_ld_p0_p100_maf_common_block H3K27ac_Hnisz_proxy_0_100_ld_p0_p100_maf_common_block 0.96204
# cS2G_promoter_ld_p0_p100_maf_common_block H3K27ac_PGC2_proxy_0_100_ld_p0_p100_maf_common_block 0.97202
# cS2G_promoter_ld_p0_p100_maf_common_block H3K4me1_Trynka_proxy_0_100_ld_p0_p100_maf_common_block 0.97283
# cS2G_promoter_ld_p0_p100_maf_common_block SuperEnhancer_Hnisz_proxy_0_100_ld_p0_p100_maf_common_block 0.97080
# cS2G_promoter_ld_p0_p100_maf_common_block H3K27ac_PGC2_proxy_0_100_ld_n100_p0_maf_common_block -0.96063
# cS2G_promoter_ld_p0_p100_maf_common_block SuperEnhancer_Hnisz_proxy_0_100_ld_n100_p0_maf_common_block -0.96714
# cS2G_promoter_ld_p0_p100_maf_common_block DGF_ENCODE_proxy_0_1000_ld_p0_p100_maf_common_block 0.95692
# cS2G_promoter_ld_p0_p100_maf_common_block Enhancer_Hoffman_proxy_0_1000_ld_p0_p100_maf_common_block 0.95794
# cS2G_promoter_ld_p0_p100_maf_common_block FetalDHS_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block 0.95916
# cS2G_promoter_ld_p0_p100_maf_common_block H3K27ac_Hnisz_proxy_0_1000_ld_p0_p100_maf_common_block 0.96274
# cS2G_promoter_ld_p0_p100_maf_common_block H3K27ac_PGC2_proxy_0_1000_ld_p0_p100_maf_common_block 0.97324
# cS2G_promoter_ld_p0_p100_maf_common_block H3K4me1_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block 0.97510
# cS2G_promoter_ld_p0_p100_maf_common_block Promoter_UCSC_proxy_0_1000_ld_p0_p100_maf_common_block 0.98791
# cS2G_promoter_ld_p0_p100_maf_common_block SuperEnhancer_Hnisz_proxy_0_1000_ld_p0_p100_maf_common_block 0.97138
# cS2G_promoter_ld_p0_p100_maf_common_block TFBS_ENCODE_proxy_0_1000_ld_p0_p100_maf_common_block 0.98563
# cS2G_promoter_ld_p0_p100_maf_common_block Enhancer_Hoffman_proxy_0_1000_ld_n100_p0_maf_common_block -0.95296
# cS2G_promoter_ld_p0_p100_maf_common_block H3K27ac_PGC2_proxy_0_1000_ld_n100_p0_maf_common_block -0.96451
# cS2G_promoter_ld_p0_p100_maf_common_block H3K4me1_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block -0.95511
# cS2G_promoter_ld_p0_p100_maf_common_block Promoter_UCSC_proxy_0_1000_ld_n100_p0_maf_common_block -0.96317
# cS2G_promoter_ld_p0_p100_maf_common_block SuperEnhancer_Hnisz_proxy_0_1000_ld_n100_p0_maf_common_block -0.96802
# cS2G_promoter_ld_p0_p100_maf_common_block TFBS_ENCODE_proxy_0_1000_ld_n100_p0_maf_common_block -0.98221
# protein_domain_ld_p0_p100_maf_common_block protein_domain_ld_n100_p0_maf_common_block -0.97103
# gene_ld_p0_p100_maf_common_block         gene_ld_n100_p0_maf_common_block         -0.99806
# cS2G_promoter_ld_n100_p0_maf_common_block H3K27ac_Hnisz_proxy_0_100_ld_p0_p100_maf_common_block -0.95786
# cS2G_promoter_ld_n100_p0_maf_common_block H3K27ac_PGC2_proxy_0_100_ld_p0_p100_maf_common_block -0.96671
# cS2G_promoter_ld_n100_p0_maf_common_block H3K4me1_Trynka_proxy_0_100_ld_p0_p100_maf_common_block -0.96780
# cS2G_promoter_ld_n100_p0_maf_common_block SuperEnhancer_Hnisz_proxy_0_100_ld_p0_p100_maf_common_block -0.95832
# cS2G_promoter_ld_n100_p0_maf_common_block H3K27ac_PGC2_proxy_0_100_ld_n100_p0_maf_common_block 0.96515
# cS2G_promoter_ld_n100_p0_maf_common_block H3K4me1_Trynka_proxy_0_100_ld_n100_p0_maf_common_block 0.95402
# cS2G_promoter_ld_n100_p0_maf_common_block SuperEnhancer_Hnisz_proxy_0_100_ld_n100_p0_maf_common_block 0.96241
# cS2G_promoter_ld_n100_p0_maf_common_block DGF_ENCODE_proxy_0_1000_ld_p0_p100_maf_common_block -0.96321
# cS2G_promoter_ld_n100_p0_maf_common_block Enhancer_Hoffman_proxy_0_1000_ld_p0_p100_maf_common_block -0.96260
# cS2G_promoter_ld_n100_p0_maf_common_block FetalDHS_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block -0.96101
# cS2G_promoter_ld_n100_p0_maf_common_block H3K27ac_Hnisz_proxy_0_1000_ld_p0_p100_maf_common_block -0.95707
# cS2G_promoter_ld_n100_p0_maf_common_block H3K27ac_PGC2_proxy_0_1000_ld_p0_p100_maf_common_block -0.96632
# cS2G_promoter_ld_n100_p0_maf_common_block H3K4me1_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block -0.96822
# cS2G_promoter_ld_n100_p0_maf_common_block Promoter_UCSC_proxy_0_1000_ld_p0_p100_maf_common_block -0.98296
# cS2G_promoter_ld_n100_p0_maf_common_block SuperEnhancer_Hnisz_proxy_0_1000_ld_p0_p100_maf_common_block -0.95799
# cS2G_promoter_ld_n100_p0_maf_common_block TFBS_ENCODE_proxy_0_1000_ld_p0_p100_maf_common_block -0.97687
# cS2G_promoter_ld_n100_p0_maf_common_block Enhancer_Hoffman_proxy_0_1000_ld_n100_p0_maf_common_block 0.96399
# cS2G_promoter_ld_n100_p0_maf_common_block H3K27ac_PGC2_proxy_0_1000_ld_n100_p0_maf_common_block 0.96796
# cS2G_promoter_ld_n100_p0_maf_common_block H3K4me1_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block 0.96103
# cS2G_promoter_ld_n100_p0_maf_common_block Promoter_UCSC_proxy_0_1000_ld_n100_p0_maf_common_block 0.97897
# cS2G_promoter_ld_n100_p0_maf_common_block SuperEnhancer_Hnisz_proxy_0_1000_ld_n100_p0_maf_common_block 0.96412
# cS2G_promoter_ld_n100_p0_maf_common_block TFBS_ENCODE_proxy_0_1000_ld_n100_p0_maf_common_block 0.98506
# H3K27ac_Hnisz_proxy_0_100_ld_p0_p100_maf_common_block H3K27ac_PGC2_proxy_0_100_ld_p0_p100_maf_common_block 0.99265
# H3K27ac_Hnisz_proxy_0_100_ld_p0_p100_maf_common_block H3K4me1_Trynka_proxy_0_100_ld_p0_p100_maf_common_block 0.99532
# H3K27ac_Hnisz_proxy_0_100_ld_p0_p100_maf_common_block SuperEnhancer_Hnisz_proxy_0_100_ld_p0_p100_maf_common_block 0.98810
# H3K27ac_Hnisz_proxy_0_100_ld_p0_p100_maf_common_block H3K27ac_Hnisz_proxy_0_100_ld_n100_p0_maf_common_block -0.99189
# H3K27ac_Hnisz_proxy_0_100_ld_p0_p100_maf_common_block H3K27ac_PGC2_proxy_0_100_ld_n100_p0_maf_common_block -0.99198
# H3K27ac_Hnisz_proxy_0_100_ld_p0_p100_maf_common_block H3K4me1_Trynka_proxy_0_100_ld_n100_p0_maf_common_block -0.98491
# H3K27ac_Hnisz_proxy_0_100_ld_p0_p100_maf_common_block SuperEnhancer_Hnisz_proxy_0_100_ld_n100_p0_maf_common_block -0.99014
# H3K27ac_Hnisz_proxy_0_100_ld_p0_p100_maf_common_block DGF_ENCODE_proxy_0_1000_ld_p0_p100_maf_common_block 0.97944
# H3K27ac_Hnisz_proxy_0_100_ld_p0_p100_maf_common_block DHS_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block 0.96827
# H3K27ac_Hnisz_proxy_0_100_ld_p0_p100_maf_common_block Enhancer_Hoffman_proxy_0_1000_ld_p0_p100_maf_common_block 0.96691
# H3K27ac_Hnisz_proxy_0_100_ld_p0_p100_maf_common_block FetalDHS_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block 0.98105
# H3K27ac_Hnisz_proxy_0_100_ld_p0_p100_maf_common_block H3K27ac_Hnisz_proxy_0_1000_ld_p0_p100_maf_common_block 0.99942
# H3K27ac_Hnisz_proxy_0_100_ld_p0_p100_maf_common_block H3K27ac_PGC2_proxy_0_1000_ld_p0_p100_maf_common_block 0.99121
# H3K27ac_Hnisz_proxy_0_100_ld_p0_p100_maf_common_block H3K4me1_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block 0.99479
# H3K27ac_Hnisz_proxy_0_100_ld_p0_p100_maf_common_block H3K4me1_peaks_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block 0.96495
# H3K27ac_Hnisz_proxy_0_100_ld_p0_p100_maf_common_block Promoter_UCSC_proxy_0_1000_ld_p0_p100_maf_common_block 0.96389
# H3K27ac_Hnisz_proxy_0_100_ld_p0_p100_maf_common_block SuperEnhancer_Hnisz_proxy_0_1000_ld_p0_p100_maf_common_block 0.98727
# H3K27ac_Hnisz_proxy_0_100_ld_p0_p100_maf_common_block TFBS_ENCODE_proxy_0_1000_ld_p0_p100_maf_common_block 0.97303
# H3K27ac_Hnisz_proxy_0_100_ld_p0_p100_maf_common_block DGF_ENCODE_proxy_0_1000_ld_n100_p0_maf_common_block -0.95428
# H3K27ac_Hnisz_proxy_0_100_ld_p0_p100_maf_common_block Enhancer_Hoffman_proxy_0_1000_ld_n100_p0_maf_common_block -0.97328
# H3K27ac_Hnisz_proxy_0_100_ld_p0_p100_maf_common_block FetalDHS_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block -0.97344
# H3K27ac_Hnisz_proxy_0_100_ld_p0_p100_maf_common_block H3K27ac_Hnisz_proxy_0_1000_ld_n100_p0_maf_common_block -0.99285
# H3K27ac_Hnisz_proxy_0_100_ld_p0_p100_maf_common_block H3K27ac_PGC2_proxy_0_1000_ld_n100_p0_maf_common_block -0.99211
# H3K27ac_Hnisz_proxy_0_100_ld_p0_p100_maf_common_block H3K4me1_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block -0.98882
# H3K27ac_Hnisz_proxy_0_100_ld_p0_p100_maf_common_block SuperEnhancer_Hnisz_proxy_0_1000_ld_n100_p0_maf_common_block -0.99085
# H3K27ac_Hnisz_proxy_0_100_ld_p0_p100_maf_common_block TFBS_ENCODE_proxy_0_1000_ld_n100_p0_maf_common_block -0.97894
# H3K27ac_PGC2_proxy_0_100_ld_p0_p100_maf_common_block H3K4me1_Trynka_proxy_0_100_ld_p0_p100_maf_common_block 0.99237
# H3K27ac_PGC2_proxy_0_100_ld_p0_p100_maf_common_block SuperEnhancer_Hnisz_proxy_0_100_ld_p0_p100_maf_common_block 0.99067
# H3K27ac_PGC2_proxy_0_100_ld_p0_p100_maf_common_block H3K27ac_Hnisz_proxy_0_100_ld_n100_p0_maf_common_block -0.97777
# H3K27ac_PGC2_proxy_0_100_ld_p0_p100_maf_common_block H3K27ac_PGC2_proxy_0_100_ld_n100_p0_maf_common_block -0.99322
# H3K27ac_PGC2_proxy_0_100_ld_p0_p100_maf_common_block H3K4me1_Trynka_proxy_0_100_ld_n100_p0_maf_common_block -0.97502
# H3K27ac_PGC2_proxy_0_100_ld_p0_p100_maf_common_block SuperEnhancer_Hnisz_proxy_0_100_ld_n100_p0_maf_common_block -0.99138
# H3K27ac_PGC2_proxy_0_100_ld_p0_p100_maf_common_block DGF_ENCODE_proxy_0_1000_ld_p0_p100_maf_common_block 0.97136
# H3K27ac_PGC2_proxy_0_100_ld_p0_p100_maf_common_block DHS_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block 0.95923
# H3K27ac_PGC2_proxy_0_100_ld_p0_p100_maf_common_block Enhancer_Hoffman_proxy_0_1000_ld_p0_p100_maf_common_block 0.97945
# H3K27ac_PGC2_proxy_0_100_ld_p0_p100_maf_common_block FetalDHS_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block 0.98058
# H3K27ac_PGC2_proxy_0_100_ld_p0_p100_maf_common_block H3K27ac_Hnisz_proxy_0_1000_ld_p0_p100_maf_common_block 0.99252
# H3K27ac_PGC2_proxy_0_100_ld_p0_p100_maf_common_block H3K27ac_PGC2_proxy_0_1000_ld_p0_p100_maf_common_block 0.99934
# H3K27ac_PGC2_proxy_0_100_ld_p0_p100_maf_common_block H3K4me1_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block 0.99370
# H3K27ac_PGC2_proxy_0_100_ld_p0_p100_maf_common_block H3K4me3_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block 0.95853
# H3K27ac_PGC2_proxy_0_100_ld_p0_p100_maf_common_block Promoter_UCSC_proxy_0_1000_ld_p0_p100_maf_common_block 0.97761
# H3K27ac_PGC2_proxy_0_100_ld_p0_p100_maf_common_block SuperEnhancer_Hnisz_proxy_0_1000_ld_p0_p100_maf_common_block 0.99075
# H3K27ac_PGC2_proxy_0_100_ld_p0_p100_maf_common_block TFBS_ENCODE_proxy_0_1000_ld_p0_p100_maf_common_block 0.98396
# H3K27ac_PGC2_proxy_0_100_ld_p0_p100_maf_common_block Vahedi_Tcell_TE_proxy_0_1000_ld_p0_p100_maf_common_block 0.95161
# H3K27ac_PGC2_proxy_0_100_ld_p0_p100_maf_common_block Enhancer_Hoffman_proxy_0_1000_ld_n100_p0_maf_common_block -0.97974
# H3K27ac_PGC2_proxy_0_100_ld_p0_p100_maf_common_block FetalDHS_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block -0.96656
# H3K27ac_PGC2_proxy_0_100_ld_p0_p100_maf_common_block H3K27ac_Hnisz_proxy_0_1000_ld_n100_p0_maf_common_block -0.97993
# H3K27ac_PGC2_proxy_0_100_ld_p0_p100_maf_common_block H3K27ac_PGC2_proxy_0_1000_ld_n100_p0_maf_common_block -0.99508
# H3K27ac_PGC2_proxy_0_100_ld_p0_p100_maf_common_block H3K4me1_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block -0.98066
# H3K27ac_PGC2_proxy_0_100_ld_p0_p100_maf_common_block H3K4me3_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block -0.95647
# H3K27ac_PGC2_proxy_0_100_ld_p0_p100_maf_common_block Promoter_UCSC_proxy_0_1000_ld_n100_p0_maf_common_block -0.95997
# H3K27ac_PGC2_proxy_0_100_ld_p0_p100_maf_common_block SuperEnhancer_Hnisz_proxy_0_1000_ld_n100_p0_maf_common_block -0.99253
# H3K27ac_PGC2_proxy_0_100_ld_p0_p100_maf_common_block TFBS_ENCODE_proxy_0_1000_ld_n100_p0_maf_common_block -0.98445
# H3K4me1_Trynka_proxy_0_100_ld_p0_p100_maf_common_block SuperEnhancer_Hnisz_proxy_0_100_ld_p0_p100_maf_common_block 0.98599
# H3K4me1_Trynka_proxy_0_100_ld_p0_p100_maf_common_block H3K27ac_Hnisz_proxy_0_100_ld_n100_p0_maf_common_block -0.98577
# H3K4me1_Trynka_proxy_0_100_ld_p0_p100_maf_common_block H3K27ac_PGC2_proxy_0_100_ld_n100_p0_maf_common_block -0.99055
# H3K4me1_Trynka_proxy_0_100_ld_p0_p100_maf_common_block H3K4me1_Trynka_proxy_0_100_ld_n100_p0_maf_common_block -0.98862
# H3K4me1_Trynka_proxy_0_100_ld_p0_p100_maf_common_block SuperEnhancer_Hnisz_proxy_0_100_ld_n100_p0_maf_common_block -0.98735
# H3K4me1_Trynka_proxy_0_100_ld_p0_p100_maf_common_block DGF_ENCODE_proxy_0_1000_ld_p0_p100_maf_common_block 0.98365
# H3K4me1_Trynka_proxy_0_100_ld_p0_p100_maf_common_block DHS_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block 0.97223
# H3K4me1_Trynka_proxy_0_100_ld_p0_p100_maf_common_block DHS_peaks_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block 0.95133
# H3K4me1_Trynka_proxy_0_100_ld_p0_p100_maf_common_block Enhancer_Hoffman_proxy_0_1000_ld_p0_p100_maf_common_block 0.96650
# H3K4me1_Trynka_proxy_0_100_ld_p0_p100_maf_common_block FetalDHS_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block 0.98456
# H3K4me1_Trynka_proxy_0_100_ld_p0_p100_maf_common_block H3K27ac_Hnisz_proxy_0_1000_ld_p0_p100_maf_common_block 0.99515
# H3K4me1_Trynka_proxy_0_100_ld_p0_p100_maf_common_block H3K27ac_PGC2_proxy_0_1000_ld_p0_p100_maf_common_block 0.99121
# H3K4me1_Trynka_proxy_0_100_ld_p0_p100_maf_common_block H3K4me1_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block 0.99896
# H3K4me1_Trynka_proxy_0_100_ld_p0_p100_maf_common_block H3K4me1_peaks_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block 0.96786
# H3K4me1_Trynka_proxy_0_100_ld_p0_p100_maf_common_block Promoter_UCSC_proxy_0_1000_ld_p0_p100_maf_common_block 0.97345
# H3K4me1_Trynka_proxy_0_100_ld_p0_p100_maf_common_block SuperEnhancer_Hnisz_proxy_0_1000_ld_p0_p100_maf_common_block 0.98560
# H3K4me1_Trynka_proxy_0_100_ld_p0_p100_maf_common_block TFBS_ENCODE_proxy_0_1000_ld_p0_p100_maf_common_block 0.97971
# H3K4me1_Trynka_proxy_0_100_ld_p0_p100_maf_common_block DGF_ENCODE_proxy_0_1000_ld_n100_p0_maf_common_block -0.95727
# H3K4me1_Trynka_proxy_0_100_ld_p0_p100_maf_common_block DHS_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block -0.95405
# H3K4me1_Trynka_proxy_0_100_ld_p0_p100_maf_common_block Enhancer_Hoffman_proxy_0_1000_ld_n100_p0_maf_common_block -0.97238
# H3K4me1_Trynka_proxy_0_100_ld_p0_p100_maf_common_block FetalDHS_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block -0.97688
# H3K4me1_Trynka_proxy_0_100_ld_p0_p100_maf_common_block H3K27ac_Hnisz_proxy_0_1000_ld_n100_p0_maf_common_block -0.98673
# H3K4me1_Trynka_proxy_0_100_ld_p0_p100_maf_common_block H3K27ac_PGC2_proxy_0_1000_ld_n100_p0_maf_common_block -0.99069
# H3K4me1_Trynka_proxy_0_100_ld_p0_p100_maf_common_block H3K4me1_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block -0.99212
# H3K4me1_Trynka_proxy_0_100_ld_p0_p100_maf_common_block H3K4me3_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block -0.95470
# H3K4me1_Trynka_proxy_0_100_ld_p0_p100_maf_common_block Promoter_UCSC_proxy_0_1000_ld_n100_p0_maf_common_block -0.95663
# H3K4me1_Trynka_proxy_0_100_ld_p0_p100_maf_common_block SuperEnhancer_Hnisz_proxy_0_1000_ld_n100_p0_maf_common_block -0.98804
# H3K4me1_Trynka_proxy_0_100_ld_p0_p100_maf_common_block TFBS_ENCODE_proxy_0_1000_ld_n100_p0_maf_common_block -0.98421
# Intron_UCSC_proxy_0_100_ld_p0_p100_maf_common_block Intron_UCSC_proxy_0_100_ld_n100_p0_maf_common_block -0.96364
# Intron_UCSC_proxy_0_100_ld_p0_p100_maf_common_block Intron_UCSC_proxy_0_1000_ld_p0_p100_maf_common_block 0.99216
# Intron_UCSC_proxy_0_100_ld_p0_p100_maf_common_block Intron_UCSC_proxy_0_1000_ld_n100_p0_maf_common_block -0.95027
# Repressed_Hoffman_proxy_0_100_ld_p0_p100_maf_common_block Repressed_Hoffman_proxy_0_100_ld_n100_p0_maf_common_block -0.98689
# Repressed_Hoffman_proxy_0_100_ld_p0_p100_maf_common_block Repressed_Hoffman_proxy_0_1000_ld_p0_p100_maf_common_block 0.99513
# Repressed_Hoffman_proxy_0_100_ld_p0_p100_maf_common_block Repressed_Hoffman_proxy_0_1000_ld_n100_p0_maf_common_block -0.98991
# SuperEnhancer_Hnisz_proxy_0_100_ld_p0_p100_maf_common_block H3K27ac_Hnisz_proxy_0_100_ld_n100_p0_maf_common_block -0.96520
# SuperEnhancer_Hnisz_proxy_0_100_ld_p0_p100_maf_common_block H3K27ac_PGC2_proxy_0_100_ld_n100_p0_maf_common_block -0.97906
# SuperEnhancer_Hnisz_proxy_0_100_ld_p0_p100_maf_common_block H3K4me1_Trynka_proxy_0_100_ld_n100_p0_maf_common_block -0.95872
# SuperEnhancer_Hnisz_proxy_0_100_ld_p0_p100_maf_common_block SuperEnhancer_Hnisz_proxy_0_100_ld_n100_p0_maf_common_block -0.99613
# SuperEnhancer_Hnisz_proxy_0_100_ld_p0_p100_maf_common_block DGF_ENCODE_proxy_0_1000_ld_p0_p100_maf_common_block 0.95475
# SuperEnhancer_Hnisz_proxy_0_100_ld_p0_p100_maf_common_block Enhancer_Hoffman_proxy_0_1000_ld_p0_p100_maf_common_block 0.97003
# SuperEnhancer_Hnisz_proxy_0_100_ld_p0_p100_maf_common_block FetalDHS_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block 0.96550
# SuperEnhancer_Hnisz_proxy_0_100_ld_p0_p100_maf_common_block H3K27ac_Hnisz_proxy_0_1000_ld_p0_p100_maf_common_block 0.98835
# SuperEnhancer_Hnisz_proxy_0_100_ld_p0_p100_maf_common_block H3K27ac_PGC2_proxy_0_1000_ld_p0_p100_maf_common_block 0.99126
# SuperEnhancer_Hnisz_proxy_0_100_ld_p0_p100_maf_common_block H3K4me1_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block 0.98761
# SuperEnhancer_Hnisz_proxy_0_100_ld_p0_p100_maf_common_block Promoter_UCSC_proxy_0_1000_ld_p0_p100_maf_common_block 0.97198
# SuperEnhancer_Hnisz_proxy_0_100_ld_p0_p100_maf_common_block SuperEnhancer_Hnisz_proxy_0_1000_ld_p0_p100_maf_common_block 0.99960
# SuperEnhancer_Hnisz_proxy_0_100_ld_p0_p100_maf_common_block TFBS_ENCODE_proxy_0_1000_ld_p0_p100_maf_common_block 0.98539
# SuperEnhancer_Hnisz_proxy_0_100_ld_p0_p100_maf_common_block Enhancer_Hoffman_proxy_0_1000_ld_n100_p0_maf_common_block -0.96699
# SuperEnhancer_Hnisz_proxy_0_100_ld_p0_p100_maf_common_block H3K27ac_Hnisz_proxy_0_1000_ld_n100_p0_maf_common_block -0.96737
# SuperEnhancer_Hnisz_proxy_0_100_ld_p0_p100_maf_common_block H3K27ac_PGC2_proxy_0_1000_ld_n100_p0_maf_common_block -0.98206
# SuperEnhancer_Hnisz_proxy_0_100_ld_p0_p100_maf_common_block H3K4me1_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block -0.96565
# SuperEnhancer_Hnisz_proxy_0_100_ld_p0_p100_maf_common_block SuperEnhancer_Hnisz_proxy_0_1000_ld_n100_p0_maf_common_block -0.99581
# SuperEnhancer_Hnisz_proxy_0_100_ld_p0_p100_maf_common_block TFBS_ENCODE_proxy_0_1000_ld_n100_p0_maf_common_block -0.98122
# Transcribed_Hoffman_proxy_0_100_ld_p0_p100_maf_common_block Transcribed_Hoffman_proxy_0_1000_ld_p0_p100_maf_common_block 0.98430
# H3K27ac_Hnisz_proxy_0_100_ld_n100_p0_maf_common_block H3K27ac_PGC2_proxy_0_100_ld_n100_p0_maf_common_block 0.98985
# H3K27ac_Hnisz_proxy_0_100_ld_n100_p0_maf_common_block H3K4me1_Trynka_proxy_0_100_ld_n100_p0_maf_common_block 0.99260
# H3K27ac_Hnisz_proxy_0_100_ld_n100_p0_maf_common_block SuperEnhancer_Hnisz_proxy_0_100_ld_n100_p0_maf_common_block 0.97612
# H3K27ac_Hnisz_proxy_0_100_ld_n100_p0_maf_common_block DGF_ENCODE_proxy_0_1000_ld_p0_p100_maf_common_block -0.98200
# H3K27ac_Hnisz_proxy_0_100_ld_n100_p0_maf_common_block DHS_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block -0.97557
# H3K27ac_Hnisz_proxy_0_100_ld_n100_p0_maf_common_block DHS_peaks_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block -0.96052
# H3K27ac_Hnisz_proxy_0_100_ld_n100_p0_maf_common_block FetalDHS_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block -0.97670
# H3K27ac_Hnisz_proxy_0_100_ld_n100_p0_maf_common_block H3K27ac_Hnisz_proxy_0_1000_ld_p0_p100_maf_common_block -0.99150
# H3K27ac_Hnisz_proxy_0_100_ld_n100_p0_maf_common_block H3K27ac_PGC2_proxy_0_1000_ld_p0_p100_maf_common_block -0.97568
# H3K27ac_Hnisz_proxy_0_100_ld_n100_p0_maf_common_block H3K4me1_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block -0.98419
# H3K27ac_Hnisz_proxy_0_100_ld_n100_p0_maf_common_block H3K4me1_peaks_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block -0.97722
# H3K27ac_Hnisz_proxy_0_100_ld_n100_p0_maf_common_block SuperEnhancer_Hnisz_proxy_0_1000_ld_p0_p100_maf_common_block -0.96419
# H3K27ac_Hnisz_proxy_0_100_ld_n100_p0_maf_common_block DGF_ENCODE_proxy_0_1000_ld_n100_p0_maf_common_block 0.97396
# H3K27ac_Hnisz_proxy_0_100_ld_n100_p0_maf_common_block DHS_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block 0.97029
# H3K27ac_Hnisz_proxy_0_100_ld_n100_p0_maf_common_block DHS_peaks_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block 0.95346
# H3K27ac_Hnisz_proxy_0_100_ld_n100_p0_maf_common_block Enhancer_Hoffman_proxy_0_1000_ld_n100_p0_maf_common_block 0.96675
# H3K27ac_Hnisz_proxy_0_100_ld_n100_p0_maf_common_block FetalDHS_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block 0.98127
# H3K27ac_Hnisz_proxy_0_100_ld_n100_p0_maf_common_block H3K27ac_Hnisz_proxy_0_1000_ld_n100_p0_maf_common_block 0.99908
# H3K27ac_Hnisz_proxy_0_100_ld_n100_p0_maf_common_block H3K27ac_PGC2_proxy_0_1000_ld_n100_p0_maf_common_block 0.98715
# H3K27ac_Hnisz_proxy_0_100_ld_n100_p0_maf_common_block H3K4me1_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block 0.99349
# H3K27ac_Hnisz_proxy_0_100_ld_n100_p0_maf_common_block H3K4me3_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block 0.95028
# H3K27ac_Hnisz_proxy_0_100_ld_n100_p0_maf_common_block SuperEnhancer_Hnisz_proxy_0_1000_ld_n100_p0_maf_common_block 0.97666
# H3K27ac_Hnisz_proxy_0_100_ld_n100_p0_maf_common_block TFBS_ENCODE_proxy_0_1000_ld_n100_p0_maf_common_block 0.96524
# H3K27ac_PGC2_proxy_0_100_ld_n100_p0_maf_common_block H3K4me1_Trynka_proxy_0_100_ld_n100_p0_maf_common_block 0.98820
# H3K27ac_PGC2_proxy_0_100_ld_n100_p0_maf_common_block SuperEnhancer_Hnisz_proxy_0_100_ld_n100_p0_maf_common_block 0.98747
# H3K27ac_PGC2_proxy_0_100_ld_n100_p0_maf_common_block DGF_ENCODE_proxy_0_1000_ld_p0_p100_maf_common_block -0.97948
# H3K27ac_PGC2_proxy_0_100_ld_n100_p0_maf_common_block DHS_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block -0.97040
# H3K27ac_PGC2_proxy_0_100_ld_n100_p0_maf_common_block DHS_peaks_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block -0.95277
# H3K27ac_PGC2_proxy_0_100_ld_n100_p0_maf_common_block Enhancer_Hoffman_proxy_0_1000_ld_p0_p100_maf_common_block -0.97312
# H3K27ac_PGC2_proxy_0_100_ld_n100_p0_maf_common_block FetalDHS_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block -0.98264
# H3K27ac_PGC2_proxy_0_100_ld_n100_p0_maf_common_block H3K27ac_Hnisz_proxy_0_1000_ld_p0_p100_maf_common_block -0.99161
# H3K27ac_PGC2_proxy_0_100_ld_n100_p0_maf_common_block H3K27ac_PGC2_proxy_0_1000_ld_p0_p100_maf_common_block -0.99209
# H3K27ac_PGC2_proxy_0_100_ld_n100_p0_maf_common_block H3K4me1_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block -0.99042
# H3K27ac_PGC2_proxy_0_100_ld_n100_p0_maf_common_block H3K4me1_peaks_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block -0.96385
# H3K27ac_PGC2_proxy_0_100_ld_n100_p0_maf_common_block Promoter_UCSC_proxy_0_1000_ld_p0_p100_maf_common_block -0.96566
# H3K27ac_PGC2_proxy_0_100_ld_n100_p0_maf_common_block SuperEnhancer_Hnisz_proxy_0_1000_ld_p0_p100_maf_common_block -0.97877
# H3K27ac_PGC2_proxy_0_100_ld_n100_p0_maf_common_block TFBS_ENCODE_proxy_0_1000_ld_p0_p100_maf_common_block -0.97111
# H3K27ac_PGC2_proxy_0_100_ld_n100_p0_maf_common_block DGF_ENCODE_proxy_0_1000_ld_n100_p0_maf_common_block 0.95883
# H3K27ac_PGC2_proxy_0_100_ld_n100_p0_maf_common_block DHS_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block 0.95581
# H3K27ac_PGC2_proxy_0_100_ld_n100_p0_maf_common_block Enhancer_Hoffman_proxy_0_1000_ld_n100_p0_maf_common_block 0.98234
# H3K27ac_PGC2_proxy_0_100_ld_n100_p0_maf_common_block FetalDHS_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block 0.97912
# H3K27ac_PGC2_proxy_0_100_ld_n100_p0_maf_common_block H3K27ac_Hnisz_proxy_0_1000_ld_n100_p0_maf_common_block 0.99063
# H3K27ac_PGC2_proxy_0_100_ld_n100_p0_maf_common_block H3K27ac_PGC2_proxy_0_1000_ld_n100_p0_maf_common_block 0.99890
# H3K27ac_PGC2_proxy_0_100_ld_n100_p0_maf_common_block H3K4me1_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block 0.99099
# H3K27ac_PGC2_proxy_0_100_ld_n100_p0_maf_common_block H3K4me3_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block 0.96309
# H3K27ac_PGC2_proxy_0_100_ld_n100_p0_maf_common_block Promoter_UCSC_proxy_0_1000_ld_n100_p0_maf_common_block 0.96004
# H3K27ac_PGC2_proxy_0_100_ld_n100_p0_maf_common_block SuperEnhancer_Hnisz_proxy_0_1000_ld_n100_p0_maf_common_block 0.98840
# H3K27ac_PGC2_proxy_0_100_ld_n100_p0_maf_common_block TFBS_ENCODE_proxy_0_1000_ld_n100_p0_maf_common_block 0.98169
# H3K4me1_Trynka_proxy_0_100_ld_n100_p0_maf_common_block SuperEnhancer_Hnisz_proxy_0_100_ld_n100_p0_maf_common_block 0.96985
# H3K4me1_Trynka_proxy_0_100_ld_n100_p0_maf_common_block DGF_ENCODE_proxy_0_1000_ld_p0_p100_maf_common_block -0.98647
# H3K4me1_Trynka_proxy_0_100_ld_n100_p0_maf_common_block DHS_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block -0.98238
# H3K4me1_Trynka_proxy_0_100_ld_n100_p0_maf_common_block DHS_peaks_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block -0.96764
# H3K4me1_Trynka_proxy_0_100_ld_n100_p0_maf_common_block FetalDHS_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block -0.98008
# H3K4me1_Trynka_proxy_0_100_ld_n100_p0_maf_common_block H3K27ac_Hnisz_proxy_0_1000_ld_p0_p100_maf_common_block -0.98401
# H3K4me1_Trynka_proxy_0_100_ld_n100_p0_maf_common_block H3K27ac_PGC2_proxy_0_1000_ld_p0_p100_maf_common_block -0.97248
# H3K4me1_Trynka_proxy_0_100_ld_n100_p0_maf_common_block H3K4me1_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block -0.98600
# H3K4me1_Trynka_proxy_0_100_ld_n100_p0_maf_common_block H3K4me1_peaks_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block -0.98082
# H3K4me1_Trynka_proxy_0_100_ld_n100_p0_maf_common_block H3K9ac_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block -0.95464
# H3K4me1_Trynka_proxy_0_100_ld_n100_p0_maf_common_block SuperEnhancer_Hnisz_proxy_0_1000_ld_p0_p100_maf_common_block -0.95760
# H3K4me1_Trynka_proxy_0_100_ld_n100_p0_maf_common_block DGF_ENCODE_proxy_0_1000_ld_n100_p0_maf_common_block 0.98095
# H3K4me1_Trynka_proxy_0_100_ld_n100_p0_maf_common_block DHS_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block 0.97994
# H3K4me1_Trynka_proxy_0_100_ld_n100_p0_maf_common_block DHS_peaks_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block 0.96379
# H3K4me1_Trynka_proxy_0_100_ld_n100_p0_maf_common_block Enhancer_Hoffman_proxy_0_1000_ld_n100_p0_maf_common_block 0.96559
# H3K4me1_Trynka_proxy_0_100_ld_n100_p0_maf_common_block FetalDHS_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block 0.98651
# H3K4me1_Trynka_proxy_0_100_ld_n100_p0_maf_common_block H3K27ac_Hnisz_proxy_0_1000_ld_n100_p0_maf_common_block 0.99137
# H3K4me1_Trynka_proxy_0_100_ld_n100_p0_maf_common_block H3K27ac_PGC2_proxy_0_1000_ld_n100_p0_maf_common_block 0.98454
# H3K4me1_Trynka_proxy_0_100_ld_n100_p0_maf_common_block H3K4me1_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block 0.99819
# H3K4me1_Trynka_proxy_0_100_ld_n100_p0_maf_common_block H3K4me3_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block 0.95874
# H3K4me1_Trynka_proxy_0_100_ld_n100_p0_maf_common_block SuperEnhancer_Hnisz_proxy_0_1000_ld_n100_p0_maf_common_block 0.97023
# H3K4me1_Trynka_proxy_0_100_ld_n100_p0_maf_common_block TFBS_ENCODE_proxy_0_1000_ld_n100_p0_maf_common_block 0.96742
# Intron_UCSC_proxy_0_100_ld_n100_p0_maf_common_block Intron_UCSC_proxy_0_1000_ld_p0_p100_maf_common_block -0.98015
# Intron_UCSC_proxy_0_100_ld_n100_p0_maf_common_block Intron_UCSC_proxy_0_1000_ld_n100_p0_maf_common_block 0.99408
# Repressed_Hoffman_proxy_0_100_ld_n100_p0_maf_common_block Repressed_Hoffman_proxy_0_1000_ld_p0_p100_maf_common_block -0.98251
# Repressed_Hoffman_proxy_0_100_ld_n100_p0_maf_common_block Repressed_Hoffman_proxy_0_1000_ld_n100_p0_maf_common_block 0.99610
# SuperEnhancer_Hnisz_proxy_0_100_ld_n100_p0_maf_common_block DGF_ENCODE_proxy_0_1000_ld_p0_p100_maf_common_block -0.96294
# SuperEnhancer_Hnisz_proxy_0_100_ld_n100_p0_maf_common_block Enhancer_Hoffman_proxy_0_1000_ld_p0_p100_maf_common_block -0.97395
# SuperEnhancer_Hnisz_proxy_0_100_ld_n100_p0_maf_common_block FetalDHS_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block -0.97234
# SuperEnhancer_Hnisz_proxy_0_100_ld_n100_p0_maf_common_block H3K27ac_Hnisz_proxy_0_1000_ld_p0_p100_maf_common_block -0.99042
# SuperEnhancer_Hnisz_proxy_0_100_ld_n100_p0_maf_common_block H3K27ac_PGC2_proxy_0_1000_ld_p0_p100_maf_common_block -0.99187
# SuperEnhancer_Hnisz_proxy_0_100_ld_n100_p0_maf_common_block H3K4me1_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block -0.98875
# SuperEnhancer_Hnisz_proxy_0_100_ld_n100_p0_maf_common_block Promoter_UCSC_proxy_0_1000_ld_p0_p100_maf_common_block -0.97014
# SuperEnhancer_Hnisz_proxy_0_100_ld_n100_p0_maf_common_block SuperEnhancer_Hnisz_proxy_0_1000_ld_p0_p100_maf_common_block -0.99593
# SuperEnhancer_Hnisz_proxy_0_100_ld_n100_p0_maf_common_block TFBS_ENCODE_proxy_0_1000_ld_p0_p100_maf_common_block -0.98130
# SuperEnhancer_Hnisz_proxy_0_100_ld_n100_p0_maf_common_block Enhancer_Hoffman_proxy_0_1000_ld_n100_p0_maf_common_block 0.97599
# SuperEnhancer_Hnisz_proxy_0_100_ld_n100_p0_maf_common_block FetalDHS_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block 0.96107
# SuperEnhancer_Hnisz_proxy_0_100_ld_n100_p0_maf_common_block H3K27ac_Hnisz_proxy_0_1000_ld_n100_p0_maf_common_block 0.97764
# SuperEnhancer_Hnisz_proxy_0_100_ld_n100_p0_maf_common_block H3K27ac_PGC2_proxy_0_1000_ld_n100_p0_maf_common_block 0.98922
# SuperEnhancer_Hnisz_proxy_0_100_ld_n100_p0_maf_common_block H3K4me1_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block 0.97556
# SuperEnhancer_Hnisz_proxy_0_100_ld_n100_p0_maf_common_block Promoter_UCSC_proxy_0_1000_ld_n100_p0_maf_common_block 0.95131
# SuperEnhancer_Hnisz_proxy_0_100_ld_n100_p0_maf_common_block SuperEnhancer_Hnisz_proxy_0_1000_ld_n100_p0_maf_common_block 0.99935
# SuperEnhancer_Hnisz_proxy_0_100_ld_n100_p0_maf_common_block TFBS_ENCODE_proxy_0_1000_ld_n100_p0_maf_common_block 0.98351
# Transcribed_Hoffman_proxy_0_100_ld_n100_p0_maf_common_block Transcribed_Hoffman_proxy_0_1000_ld_n100_p0_maf_common_block 0.96683
# DGF_ENCODE_proxy_0_1000_ld_p0_p100_maf_common_block DHS_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block 0.98752
# DGF_ENCODE_proxy_0_1000_ld_p0_p100_maf_common_block DHS_peaks_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block 0.97571
# DGF_ENCODE_proxy_0_1000_ld_p0_p100_maf_common_block Enhancer_Hoffman_proxy_0_1000_ld_p0_p100_maf_common_block 0.95556
# DGF_ENCODE_proxy_0_1000_ld_p0_p100_maf_common_block FetalDHS_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block 0.98392
# DGF_ENCODE_proxy_0_1000_ld_p0_p100_maf_common_block H3K27ac_Hnisz_proxy_0_1000_ld_p0_p100_maf_common_block 0.97873
# DGF_ENCODE_proxy_0_1000_ld_p0_p100_maf_common_block H3K27ac_PGC2_proxy_0_1000_ld_p0_p100_maf_common_block 0.96906
# DGF_ENCODE_proxy_0_1000_ld_p0_p100_maf_common_block H3K4me1_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block 0.98231
# DGF_ENCODE_proxy_0_1000_ld_p0_p100_maf_common_block H3K4me1_peaks_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block 0.98490
# DGF_ENCODE_proxy_0_1000_ld_p0_p100_maf_common_block H3K9ac_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block 0.96330
# DGF_ENCODE_proxy_0_1000_ld_p0_p100_maf_common_block Promoter_UCSC_proxy_0_1000_ld_p0_p100_maf_common_block 0.95790
# DGF_ENCODE_proxy_0_1000_ld_p0_p100_maf_common_block SuperEnhancer_Hnisz_proxy_0_1000_ld_p0_p100_maf_common_block 0.95377
# DGF_ENCODE_proxy_0_1000_ld_p0_p100_maf_common_block TFBS_ENCODE_proxy_0_1000_ld_p0_p100_maf_common_block 0.95629
# DGF_ENCODE_proxy_0_1000_ld_p0_p100_maf_common_block DGF_ENCODE_proxy_0_1000_ld_n100_p0_maf_common_block -0.98438
# DGF_ENCODE_proxy_0_1000_ld_p0_p100_maf_common_block DHS_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block -0.97115
# DGF_ENCODE_proxy_0_1000_ld_p0_p100_maf_common_block DHS_peaks_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block -0.95328
# DGF_ENCODE_proxy_0_1000_ld_p0_p100_maf_common_block Enhancer_Hoffman_proxy_0_1000_ld_n100_p0_maf_common_block -0.96577
# DGF_ENCODE_proxy_0_1000_ld_p0_p100_maf_common_block FetalDHS_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block -0.97852
# DGF_ENCODE_proxy_0_1000_ld_p0_p100_maf_common_block H3K27ac_Hnisz_proxy_0_1000_ld_n100_p0_maf_common_block -0.98228
# DGF_ENCODE_proxy_0_1000_ld_p0_p100_maf_common_block H3K27ac_PGC2_proxy_0_1000_ld_n100_p0_maf_common_block -0.97815
# DGF_ENCODE_proxy_0_1000_ld_p0_p100_maf_common_block H3K4me1_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block -0.98915
# DGF_ENCODE_proxy_0_1000_ld_p0_p100_maf_common_block H3K4me3_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block -0.95905
# DGF_ENCODE_proxy_0_1000_ld_p0_p100_maf_common_block Promoter_UCSC_proxy_0_1000_ld_n100_p0_maf_common_block -0.95736
# DGF_ENCODE_proxy_0_1000_ld_p0_p100_maf_common_block SuperEnhancer_Hnisz_proxy_0_1000_ld_n100_p0_maf_common_block -0.96489
# DGF_ENCODE_proxy_0_1000_ld_p0_p100_maf_common_block TFBS_ENCODE_proxy_0_1000_ld_n100_p0_maf_common_block -0.97337
# DHS_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block DHS_peaks_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block 0.99305
# DHS_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block FetalDHS_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block 0.98782
# DHS_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block H3K27ac_Hnisz_proxy_0_1000_ld_p0_p100_maf_common_block 0.96724
# DHS_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block H3K27ac_PGC2_proxy_0_1000_ld_p0_p100_maf_common_block 0.95624
# DHS_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block H3K4me1_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block 0.97047
# DHS_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block H3K4me1_peaks_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block 0.97979
# DHS_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block H3K9ac_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block 0.96324
# DHS_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block DGF_ENCODE_proxy_0_1000_ld_n100_p0_maf_common_block -0.97575
# DHS_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block DHS_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block -0.98389
# DHS_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block DHS_peaks_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block -0.96649
# DHS_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block Enhancer_Hoffman_proxy_0_1000_ld_n100_p0_maf_common_block -0.95430
# DHS_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block FetalDHS_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block -0.98291
# DHS_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block H3K27ac_Hnisz_proxy_0_1000_ld_n100_p0_maf_common_block -0.97467
# DHS_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block H3K27ac_PGC2_proxy_0_1000_ld_n100_p0_maf_common_block -0.96676
# DHS_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block H3K4me1_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block -0.98213
# DHS_peaks_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block FetalDHS_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block 0.97698
# DHS_peaks_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block H3K4me1_peaks_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block 0.97105
# DHS_peaks_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block H3K9ac_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block 0.96384
# DHS_peaks_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block DGF_ENCODE_proxy_0_1000_ld_n100_p0_maf_common_block -0.96822
# DHS_peaks_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block DHS_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block -0.97566
# DHS_peaks_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block DHS_peaks_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block -0.96746
# DHS_peaks_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block FetalDHS_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block -0.97196
# DHS_peaks_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block H3K27ac_Hnisz_proxy_0_1000_ld_n100_p0_maf_common_block -0.95950
# DHS_peaks_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block H3K4me1_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block -0.96657
# Enhancer_Hoffman_proxy_0_1000_ld_p0_p100_maf_common_block FetalDHS_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block 0.96933
# Enhancer_Hoffman_proxy_0_1000_ld_p0_p100_maf_common_block H3K27ac_Hnisz_proxy_0_1000_ld_p0_p100_maf_common_block 0.96690
# Enhancer_Hoffman_proxy_0_1000_ld_p0_p100_maf_common_block H3K27ac_PGC2_proxy_0_1000_ld_p0_p100_maf_common_block 0.98021
# Enhancer_Hoffman_proxy_0_1000_ld_p0_p100_maf_common_block H3K4me1_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block 0.97031
# Enhancer_Hoffman_proxy_0_1000_ld_p0_p100_maf_common_block Promoter_UCSC_proxy_0_1000_ld_p0_p100_maf_common_block 0.96939
# Enhancer_Hoffman_proxy_0_1000_ld_p0_p100_maf_common_block SuperEnhancer_Hnisz_proxy_0_1000_ld_p0_p100_maf_common_block 0.97108
# Enhancer_Hoffman_proxy_0_1000_ld_p0_p100_maf_common_block TFBS_ENCODE_proxy_0_1000_ld_p0_p100_maf_common_block 0.97331
# Enhancer_Hoffman_proxy_0_1000_ld_p0_p100_maf_common_block Enhancer_Hoffman_proxy_0_1000_ld_n100_p0_maf_common_block -0.99022
# Enhancer_Hoffman_proxy_0_1000_ld_p0_p100_maf_common_block H3K27ac_Hnisz_proxy_0_1000_ld_n100_p0_maf_common_block -0.95410
# Enhancer_Hoffman_proxy_0_1000_ld_p0_p100_maf_common_block H3K27ac_PGC2_proxy_0_1000_ld_n100_p0_maf_common_block -0.97771
# Enhancer_Hoffman_proxy_0_1000_ld_p0_p100_maf_common_block H3K4me1_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block -0.95596
# Enhancer_Hoffman_proxy_0_1000_ld_p0_p100_maf_common_block Promoter_UCSC_proxy_0_1000_ld_n100_p0_maf_common_block -0.96097
# Enhancer_Hoffman_proxy_0_1000_ld_p0_p100_maf_common_block SuperEnhancer_Hnisz_proxy_0_1000_ld_n100_p0_maf_common_block -0.97722
# Enhancer_Hoffman_proxy_0_1000_ld_p0_p100_maf_common_block TFBS_ENCODE_proxy_0_1000_ld_n100_p0_maf_common_block -0.97594
# FetalDHS_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block H3K27ac_Hnisz_proxy_0_1000_ld_p0_p100_maf_common_block 0.98090
# FetalDHS_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block H3K27ac_PGC2_proxy_0_1000_ld_p0_p100_maf_common_block 0.97959
# FetalDHS_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block H3K4me1_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block 0.98515
# FetalDHS_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block H3K4me1_peaks_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block 0.96902
# FetalDHS_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block Promoter_UCSC_proxy_0_1000_ld_p0_p100_maf_common_block 0.96565
# FetalDHS_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block SuperEnhancer_Hnisz_proxy_0_1000_ld_p0_p100_maf_common_block 0.96557
# FetalDHS_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block TFBS_ENCODE_proxy_0_1000_ld_p0_p100_maf_common_block 0.96196
# FetalDHS_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block DGF_ENCODE_proxy_0_1000_ld_n100_p0_maf_common_block -0.95754
# FetalDHS_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block DHS_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block -0.96227
# FetalDHS_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block Enhancer_Hoffman_proxy_0_1000_ld_n100_p0_maf_common_block -0.97267
# FetalDHS_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block FetalDHS_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block -0.98664
# FetalDHS_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block H3K27ac_Hnisz_proxy_0_1000_ld_n100_p0_maf_common_block -0.97768
# FetalDHS_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block H3K27ac_PGC2_proxy_0_1000_ld_n100_p0_maf_common_block -0.98213
# FetalDHS_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block H3K4me1_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block -0.98349
# FetalDHS_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block H3K4me3_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block -0.95271
# FetalDHS_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block Promoter_UCSC_proxy_0_1000_ld_n100_p0_maf_common_block -0.95818
# FetalDHS_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block SuperEnhancer_Hnisz_proxy_0_1000_ld_n100_p0_maf_common_block -0.97398
# FetalDHS_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block TFBS_ENCODE_proxy_0_1000_ld_n100_p0_maf_common_block -0.97094
# H3K27ac_Hnisz_proxy_0_1000_ld_p0_p100_maf_common_block H3K27ac_PGC2_proxy_0_1000_ld_p0_p100_maf_common_block 0.99194
# H3K27ac_Hnisz_proxy_0_1000_ld_p0_p100_maf_common_block H3K4me1_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block 0.99551
# H3K27ac_Hnisz_proxy_0_1000_ld_p0_p100_maf_common_block H3K4me1_peaks_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block 0.96489
# H3K27ac_Hnisz_proxy_0_1000_ld_p0_p100_maf_common_block Promoter_UCSC_proxy_0_1000_ld_p0_p100_maf_common_block 0.96410
# H3K27ac_Hnisz_proxy_0_1000_ld_p0_p100_maf_common_block SuperEnhancer_Hnisz_proxy_0_1000_ld_p0_p100_maf_common_block 0.98823
# H3K27ac_Hnisz_proxy_0_1000_ld_p0_p100_maf_common_block TFBS_ENCODE_proxy_0_1000_ld_p0_p100_maf_common_block 0.97372
# H3K27ac_Hnisz_proxy_0_1000_ld_p0_p100_maf_common_block DGF_ENCODE_proxy_0_1000_ld_n100_p0_maf_common_block -0.95250
# H3K27ac_Hnisz_proxy_0_1000_ld_p0_p100_maf_common_block Enhancer_Hoffman_proxy_0_1000_ld_n100_p0_maf_common_block -0.97271
# H3K27ac_Hnisz_proxy_0_1000_ld_p0_p100_maf_common_block FetalDHS_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block -0.97270
# H3K27ac_Hnisz_proxy_0_1000_ld_p0_p100_maf_common_block H3K27ac_Hnisz_proxy_0_1000_ld_n100_p0_maf_common_block -0.99289
# H3K27ac_Hnisz_proxy_0_1000_ld_p0_p100_maf_common_block H3K27ac_PGC2_proxy_0_1000_ld_n100_p0_maf_common_block -0.99207
# H3K27ac_Hnisz_proxy_0_1000_ld_p0_p100_maf_common_block H3K4me1_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block -0.98849
# H3K27ac_Hnisz_proxy_0_1000_ld_p0_p100_maf_common_block SuperEnhancer_Hnisz_proxy_0_1000_ld_n100_p0_maf_common_block -0.99138
# H3K27ac_Hnisz_proxy_0_1000_ld_p0_p100_maf_common_block TFBS_ENCODE_proxy_0_1000_ld_n100_p0_maf_common_block -0.97854
# H3K27ac_PGC2_proxy_0_1000_ld_p0_p100_maf_common_block H3K4me1_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block 0.99358
# H3K27ac_PGC2_proxy_0_1000_ld_p0_p100_maf_common_block H3K4me3_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block 0.95764
# H3K27ac_PGC2_proxy_0_1000_ld_p0_p100_maf_common_block Promoter_UCSC_proxy_0_1000_ld_p0_p100_maf_common_block 0.97858
# H3K27ac_PGC2_proxy_0_1000_ld_p0_p100_maf_common_block SuperEnhancer_Hnisz_proxy_0_1000_ld_p0_p100_maf_common_block 0.99198
# H3K27ac_PGC2_proxy_0_1000_ld_p0_p100_maf_common_block TFBS_ENCODE_proxy_0_1000_ld_p0_p100_maf_common_block 0.98517
# H3K27ac_PGC2_proxy_0_1000_ld_p0_p100_maf_common_block Vahedi_Tcell_TE_proxy_0_1000_ld_p0_p100_maf_common_block 0.95297
# H3K27ac_PGC2_proxy_0_1000_ld_p0_p100_maf_common_block Enhancer_Hoffman_proxy_0_1000_ld_n100_p0_maf_common_block -0.97948
# H3K27ac_PGC2_proxy_0_1000_ld_p0_p100_maf_common_block FetalDHS_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block -0.96484
# H3K27ac_PGC2_proxy_0_1000_ld_p0_p100_maf_common_block H3K27ac_Hnisz_proxy_0_1000_ld_n100_p0_maf_common_block -0.97814
# H3K27ac_PGC2_proxy_0_1000_ld_p0_p100_maf_common_block H3K27ac_PGC2_proxy_0_1000_ld_n100_p0_maf_common_block -0.99449
# H3K27ac_PGC2_proxy_0_1000_ld_p0_p100_maf_common_block H3K4me1_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block -0.97873
# H3K27ac_PGC2_proxy_0_1000_ld_p0_p100_maf_common_block H3K4me3_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block -0.95430
# H3K27ac_PGC2_proxy_0_1000_ld_p0_p100_maf_common_block Promoter_UCSC_proxy_0_1000_ld_n100_p0_maf_common_block -0.95904
# H3K27ac_PGC2_proxy_0_1000_ld_p0_p100_maf_common_block SuperEnhancer_Hnisz_proxy_0_1000_ld_n100_p0_maf_common_block -0.99308
# H3K27ac_PGC2_proxy_0_1000_ld_p0_p100_maf_common_block TFBS_ENCODE_proxy_0_1000_ld_n100_p0_maf_common_block -0.98428
# H3K4me1_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block H3K4me1_peaks_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block 0.96565
# H3K4me1_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block Promoter_UCSC_proxy_0_1000_ld_p0_p100_maf_common_block 0.97556
# H3K4me1_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block SuperEnhancer_Hnisz_proxy_0_1000_ld_p0_p100_maf_common_block 0.98787
# H3K4me1_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block TFBS_ENCODE_proxy_0_1000_ld_p0_p100_maf_common_block 0.98197
# H3K4me1_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block DGF_ENCODE_proxy_0_1000_ld_n100_p0_maf_common_block -0.95304
# H3K4me1_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block Enhancer_Hoffman_proxy_0_1000_ld_n100_p0_maf_common_block -0.97458
# H3K4me1_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block FetalDHS_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block -0.97560
# H3K4me1_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block H3K27ac_Hnisz_proxy_0_1000_ld_n100_p0_maf_common_block -0.98564
# H3K4me1_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block H3K27ac_PGC2_proxy_0_1000_ld_n100_p0_maf_common_block -0.99124
# H3K4me1_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block H3K4me1_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block -0.99074
# H3K4me1_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block H3K4me3_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block -0.95252
# H3K4me1_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block Promoter_UCSC_proxy_0_1000_ld_n100_p0_maf_common_block -0.95651
# H3K4me1_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block SuperEnhancer_Hnisz_proxy_0_1000_ld_n100_p0_maf_common_block -0.98969
# H3K4me1_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block TFBS_ENCODE_proxy_0_1000_ld_n100_p0_maf_common_block -0.98442
# H3K4me1_peaks_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block H3K9ac_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block 0.98101
# H3K4me1_peaks_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block DGF_ENCODE_proxy_0_1000_ld_n100_p0_maf_common_block -0.98254
# H3K4me1_peaks_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block DHS_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block -0.97520
# H3K4me1_peaks_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block DHS_peaks_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block -0.96240
# H3K4me1_peaks_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block FetalDHS_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block -0.97480
# H3K4me1_peaks_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block H3K27ac_Hnisz_proxy_0_1000_ld_n100_p0_maf_common_block -0.97825
# H3K4me1_peaks_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block H3K27ac_PGC2_proxy_0_1000_ld_n100_p0_maf_common_block -0.96143
# H3K4me1_peaks_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block H3K4me1_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block -0.98331
# H3K4me1_peaks_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block H3K4me1_peaks_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block -0.97091
# H3K4me1_peaks_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block H3K9ac_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block -0.95092
# H3K4me3_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block Promoter_UCSC_proxy_0_1000_ld_p0_p100_maf_common_block 0.95250
# H3K4me3_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block H3K4me3_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block -0.98079
# H3K9ac_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block DGF_ENCODE_proxy_0_1000_ld_n100_p0_maf_common_block -0.96840
# H3K9ac_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block DHS_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block -0.95743
# H3K9ac_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block H3K4me1_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block -0.95518
# H3K9ac_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block H3K4me1_peaks_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block -0.96322
# H3K9ac_Trynka_proxy_0_1000_ld_p0_p100_maf_common_block H3K9ac_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block -0.97748
# Intron_UCSC_proxy_0_1000_ld_p0_p100_maf_common_block Intron_UCSC_proxy_0_1000_ld_n100_p0_maf_common_block -0.97399
# Promoter_UCSC_proxy_0_1000_ld_p0_p100_maf_common_block SuperEnhancer_Hnisz_proxy_0_1000_ld_p0_p100_maf_common_block 0.97264
# Promoter_UCSC_proxy_0_1000_ld_p0_p100_maf_common_block TFBS_ENCODE_proxy_0_1000_ld_p0_p100_maf_common_block 0.98816
# Promoter_UCSC_proxy_0_1000_ld_p0_p100_maf_common_block Enhancer_Hoffman_proxy_0_1000_ld_n100_p0_maf_common_block -0.96296
# Promoter_UCSC_proxy_0_1000_ld_p0_p100_maf_common_block H3K27ac_PGC2_proxy_0_1000_ld_n100_p0_maf_common_block -0.96999
# Promoter_UCSC_proxy_0_1000_ld_p0_p100_maf_common_block H3K4me1_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block -0.95573
# Promoter_UCSC_proxy_0_1000_ld_p0_p100_maf_common_block Promoter_UCSC_proxy_0_1000_ld_n100_p0_maf_common_block -0.98517
# Promoter_UCSC_proxy_0_1000_ld_p0_p100_maf_common_block SuperEnhancer_Hnisz_proxy_0_1000_ld_n100_p0_maf_common_block -0.97173
# Promoter_UCSC_proxy_0_1000_ld_p0_p100_maf_common_block TFBS_ENCODE_proxy_0_1000_ld_n100_p0_maf_common_block -0.98507
# Repressed_Hoffman_proxy_0_1000_ld_p0_p100_maf_common_block Repressed_Hoffman_proxy_0_1000_ld_n100_p0_maf_common_block -0.98976
# SuperEnhancer_Hnisz_proxy_0_1000_ld_p0_p100_maf_common_block TFBS_ENCODE_proxy_0_1000_ld_p0_p100_maf_common_block 0.98597
# SuperEnhancer_Hnisz_proxy_0_1000_ld_p0_p100_maf_common_block Enhancer_Hoffman_proxy_0_1000_ld_n100_p0_maf_common_block -0.96708
# SuperEnhancer_Hnisz_proxy_0_1000_ld_p0_p100_maf_common_block H3K27ac_Hnisz_proxy_0_1000_ld_n100_p0_maf_common_block -0.96665
# SuperEnhancer_Hnisz_proxy_0_1000_ld_p0_p100_maf_common_block H3K27ac_PGC2_proxy_0_1000_ld_n100_p0_maf_common_block -0.98204
# SuperEnhancer_Hnisz_proxy_0_1000_ld_p0_p100_maf_common_block H3K4me1_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block -0.96492
# SuperEnhancer_Hnisz_proxy_0_1000_ld_p0_p100_maf_common_block SuperEnhancer_Hnisz_proxy_0_1000_ld_n100_p0_maf_common_block -0.99586
# SuperEnhancer_Hnisz_proxy_0_1000_ld_p0_p100_maf_common_block TFBS_ENCODE_proxy_0_1000_ld_n100_p0_maf_common_block -0.98090
# TFBS_ENCODE_proxy_0_1000_ld_p0_p100_maf_common_block Enhancer_Hoffman_proxy_0_1000_ld_n100_p0_maf_common_block -0.96935
# TFBS_ENCODE_proxy_0_1000_ld_p0_p100_maf_common_block H3K27ac_Hnisz_proxy_0_1000_ld_n100_p0_maf_common_block -0.95281
# TFBS_ENCODE_proxy_0_1000_ld_p0_p100_maf_common_block H3K27ac_PGC2_proxy_0_1000_ld_n100_p0_maf_common_block -0.97619
# TFBS_ENCODE_proxy_0_1000_ld_p0_p100_maf_common_block H3K4me1_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block -0.95895
# TFBS_ENCODE_proxy_0_1000_ld_p0_p100_maf_common_block Promoter_UCSC_proxy_0_1000_ld_n100_p0_maf_common_block -0.96030
# TFBS_ENCODE_proxy_0_1000_ld_p0_p100_maf_common_block SuperEnhancer_Hnisz_proxy_0_1000_ld_n100_p0_maf_common_block -0.98287
# TFBS_ENCODE_proxy_0_1000_ld_p0_p100_maf_common_block TFBS_ENCODE_proxy_0_1000_ld_n100_p0_maf_common_block -0.99340
# Vahedi_Tcell_TE_proxy_0_1000_ld_p0_p100_maf_common_block Vahedi_Tcell_TE_proxy_0_1000_ld_n100_p0_maf_common_block -0.98024
# DGF_ENCODE_proxy_0_1000_ld_n100_p0_maf_common_block DHS_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block 0.98540
# DGF_ENCODE_proxy_0_1000_ld_n100_p0_maf_common_block DHS_peaks_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block 0.97929
# DGF_ENCODE_proxy_0_1000_ld_n100_p0_maf_common_block FetalDHS_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block 0.97448
# DGF_ENCODE_proxy_0_1000_ld_n100_p0_maf_common_block H3K27ac_Hnisz_proxy_0_1000_ld_n100_p0_maf_common_block 0.97184
# DGF_ENCODE_proxy_0_1000_ld_n100_p0_maf_common_block H3K27ac_PGC2_proxy_0_1000_ld_n100_p0_maf_common_block 0.95371
# DGF_ENCODE_proxy_0_1000_ld_n100_p0_maf_common_block H3K4me1_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block 0.97911
# DGF_ENCODE_proxy_0_1000_ld_n100_p0_maf_common_block H3K4me1_peaks_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block 0.96685
# DGF_ENCODE_proxy_0_1000_ld_n100_p0_maf_common_block H3K9ac_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block 0.95108
# DHS_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block DHS_peaks_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block 0.99158
# DHS_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block FetalDHS_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block 0.98428
# DHS_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block H3K27ac_Hnisz_proxy_0_1000_ld_n100_p0_maf_common_block 0.96732
# DHS_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block H3K4me1_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block 0.97595
# DHS_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block H3K4me1_peaks_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block 0.96222
# DHS_peaks_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block FetalDHS_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block 0.97191
# DHS_peaks_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block H3K4me1_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block 0.95832
# DHS_peaks_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block H3K4me1_peaks_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block 0.96472
# Enhancer_Hoffman_proxy_0_1000_ld_n100_p0_maf_common_block FetalDHS_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block 0.96449
# Enhancer_Hoffman_proxy_0_1000_ld_n100_p0_maf_common_block H3K27ac_Hnisz_proxy_0_1000_ld_n100_p0_maf_common_block 0.96988
# Enhancer_Hoffman_proxy_0_1000_ld_n100_p0_maf_common_block H3K27ac_PGC2_proxy_0_1000_ld_n100_p0_maf_common_block 0.98494
# Enhancer_Hoffman_proxy_0_1000_ld_n100_p0_maf_common_block H3K4me1_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block 0.97173
# Enhancer_Hoffman_proxy_0_1000_ld_n100_p0_maf_common_block Promoter_UCSC_proxy_0_1000_ld_n100_p0_maf_common_block 0.96014
# Enhancer_Hoffman_proxy_0_1000_ld_n100_p0_maf_common_block SuperEnhancer_Hnisz_proxy_0_1000_ld_n100_p0_maf_common_block 0.97867
# Enhancer_Hoffman_proxy_0_1000_ld_n100_p0_maf_common_block TFBS_ENCODE_proxy_0_1000_ld_n100_p0_maf_common_block 0.97751
# FetalDHS_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block H3K27ac_Hnisz_proxy_0_1000_ld_n100_p0_maf_common_block 0.98075
# FetalDHS_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block H3K27ac_PGC2_proxy_0_1000_ld_n100_p0_maf_common_block 0.97643
# FetalDHS_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block H3K4me1_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block 0.98696
# FetalDHS_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block H3K4me3_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block 0.95413
# FetalDHS_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block SuperEnhancer_Hnisz_proxy_0_1000_ld_n100_p0_maf_common_block 0.96178
# FetalDHS_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block TFBS_ENCODE_proxy_0_1000_ld_n100_p0_maf_common_block 0.95961
# H3K27ac_Hnisz_proxy_0_1000_ld_n100_p0_maf_common_block H3K27ac_PGC2_proxy_0_1000_ld_n100_p0_maf_common_block 0.98937
# H3K27ac_Hnisz_proxy_0_1000_ld_n100_p0_maf_common_block H3K4me1_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block 0.99402
# H3K27ac_Hnisz_proxy_0_1000_ld_n100_p0_maf_common_block SuperEnhancer_Hnisz_proxy_0_1000_ld_n100_p0_maf_common_block 0.97930
# H3K27ac_Hnisz_proxy_0_1000_ld_n100_p0_maf_common_block TFBS_ENCODE_proxy_0_1000_ld_n100_p0_maf_common_block 0.96764
# H3K27ac_PGC2_proxy_0_1000_ld_n100_p0_maf_common_block H3K4me1_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block 0.98935
# H3K27ac_PGC2_proxy_0_1000_ld_n100_p0_maf_common_block H3K4me3_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block 0.96150
# H3K27ac_PGC2_proxy_0_1000_ld_n100_p0_maf_common_block Promoter_UCSC_proxy_0_1000_ld_n100_p0_maf_common_block 0.96240
# H3K27ac_PGC2_proxy_0_1000_ld_n100_p0_maf_common_block SuperEnhancer_Hnisz_proxy_0_1000_ld_n100_p0_maf_common_block 0.99103
# H3K27ac_PGC2_proxy_0_1000_ld_n100_p0_maf_common_block TFBS_ENCODE_proxy_0_1000_ld_n100_p0_maf_common_block 0.98479
# H3K4me1_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block H3K4me3_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block 0.95899
# H3K4me1_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block Promoter_UCSC_proxy_0_1000_ld_n100_p0_maf_common_block 0.95318
# H3K4me1_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block SuperEnhancer_Hnisz_proxy_0_1000_ld_n100_p0_maf_common_block 0.97698
# H3K4me1_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block TFBS_ENCODE_proxy_0_1000_ld_n100_p0_maf_common_block 0.97423
# H3K4me1_peaks_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block H3K9ac_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block 0.97756
# H3K4me3_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block Promoter_UCSC_proxy_0_1000_ld_n100_p0_maf_common_block 0.95278
# H3K4me3_Trynka_proxy_0_1000_ld_n100_p0_maf_common_block TFBS_ENCODE_proxy_0_1000_ld_n100_p0_maf_common_block 0.95195
# Promoter_UCSC_proxy_0_1000_ld_n100_p0_maf_common_block SuperEnhancer_Hnisz_proxy_0_1000_ld_n100_p0_maf_common_block 0.95358
# Promoter_UCSC_proxy_0_1000_ld_n100_p0_maf_common_block TFBS_ENCODE_proxy_0_1000_ld_n100_p0_maf_common_block 0.97269
# SuperEnhancer_Hnisz_proxy_0_1000_ld_n100_p0_maf_common_block TFBS_ENCODE_proxy_0_1000_ld_n100_p0_maf_common_block 0.98506
#
# lf lf
# proxy_0_100_ld_p0_p100_maf_lf_block      proxy_100_1000_ld_p0_p100_maf_lf_block   0.97624
# proxy_100_1000_ld_p0_p100_maf_lf_block   proxy_1000_10000_ld_p0_p100_maf_lf_block 0.96270
# proxy_0_100_ld_n100_p0_maf_lf_block      proxy_100_1000_ld_n100_p0_maf_lf_block   0.97629
# proxy_0_100_ld_n100_p0_maf_lf_block      proxy_1000_10000_ld_n100_p0_maf_lf_block 0.95097
# proxy_100_1000_ld_n100_p0_maf_lf_block   proxy_1000_10000_ld_n100_p0_maf_lf_block 0.97715
# exon_ld_p0_p100_maf_lf_block             exon_ld_n100_p0_maf_lf_block             -0.96818
# protein_domain_ld_p0_p100_maf_lf_block   protein_domain_ld_n100_p0_maf_lf_block   -0.98411
# gene_ld_p0_p100_maf_lf_block             gene_ld_n100_p0_maf_lf_block             -0.97001
# H3K27ac_Hnisz_proxy_0_100_ld_p0_p100_maf_lf_block H3K27ac_Hnisz_proxy_0_1000_ld_p0_p100_maf_lf_block 0.95802
# H3K27ac_PGC2_proxy_0_100_ld_p0_p100_maf_lf_block H3K27ac_PGC2_proxy_0_1000_ld_p0_p100_maf_lf_block 0.95460
# H3K4me1_Trynka_proxy_0_100_ld_p0_p100_maf_lf_block H3K4me1_Trynka_proxy_0_1000_ld_p0_p100_maf_lf_block 0.95699
# Intron_UCSC_proxy_0_100_ld_p0_p100_maf_lf_block Intron_UCSC_proxy_0_1000_ld_p0_p100_maf_lf_block 0.97309
# Repressed_Hoffman_proxy_0_100_ld_p0_p100_maf_lf_block Repressed_Hoffman_proxy_0_1000_ld_p0_p100_maf_lf_block 0.97773
# SuperEnhancer_Hnisz_proxy_0_100_ld_p0_p100_maf_lf_block SuperEnhancer_Hnisz_proxy_0_1000_ld_p0_p100_maf_lf_block 0.96685
# H3K27ac_Hnisz_proxy_0_100_ld_n100_p0_maf_lf_block H3K27ac_Hnisz_proxy_0_1000_ld_n100_p0_maf_lf_block 0.97182
# H3K27ac_PGC2_proxy_0_100_ld_n100_p0_maf_lf_block H3K27ac_PGC2_proxy_0_1000_ld_n100_p0_maf_lf_block 0.95702
# H3K4me1_Trynka_proxy_0_100_ld_n100_p0_maf_lf_block H3K4me1_Trynka_proxy_0_1000_ld_n100_p0_maf_lf_block 0.95887
# Intron_UCSC_proxy_0_100_ld_n100_p0_maf_lf_block Intron_UCSC_proxy_0_1000_ld_p0_p100_maf_lf_block -0.96065
# Intron_UCSC_proxy_0_100_ld_n100_p0_maf_lf_block Intron_UCSC_proxy_0_1000_ld_n100_p0_maf_lf_block 0.98096
# Repressed_Hoffman_proxy_0_100_ld_n100_p0_maf_lf_block Repressed_Hoffman_proxy_0_1000_ld_n100_p0_maf_lf_block 0.97826
# SuperEnhancer_Hnisz_proxy_0_100_ld_n100_p0_maf_lf_block SuperEnhancer_Hnisz_proxy_0_1000_ld_n100_p0_maf_lf_block 0.97539
# Intron_UCSC_proxy_0_1000_ld_p0_p100_maf_lf_block Intron_UCSC_proxy_0_1000_ld_n100_p0_maf_lf_block -0.96966
# Transcribed_Hoffman_proxy_0_1000_ld_p0_p100_maf_lf_block Transcribed_Hoffman_proxy_0_1000_ld_n100_p0_maf_lf_block -0.95247
# Vahedi_Tcell_SE_proxy_0_1000_ld_p0_p100_maf_lf_block Vahedi_Tcell_SE_proxy_0_1000_ld_n100_p0_maf_lf_block -0.97819
# Vahedi_Tcell_TE_proxy_0_1000_ld_p0_p100_maf_lf_block Vahedi_Tcell_TE_proxy_0_1000_ld_n100_p0_maf_lf_block -0.96444

# %%
for mbin in ['common', 'lf']:
    temp_list = [x for x in df_cor if ('p0' in x) & (mbin in x)]
    temp_df = df_cor.loc[temp_list, temp_list].copy()
    temp_df.columns = [x.replace('pAN:proxy_', '').replace('_maf', '').replace('_block', '') for x in temp_df]
    temp_df.index = [x.replace('pAN:proxy_', '').replace('_maf', '').replace('_block', '') for x in temp_df.index]
    plt.figure(figsize=[5,5])
    sns.heatmap(temp_df, vmax=1, vmin=-1, cmap='RdBu_r', annot=temp_df, fmt='0.4g')
    plt.show()
#     display(df_cor.loc[temp_list, temp_list])

# %%
np.corrcoef(df_score['pAN:proxy_0_100_common_common'], df_score['pAN:proxy_0_1000_common_common'])[0,1]
# Out:
# 0.9928360190214107

# %%
np.corrcoef(df_score['pAN:proxy_0_100_common_common'], 
            df_score['pAN:proxy_0_1000_common_common'] - df_score['pAN:proxy_0_100_common_common'])[0,1]
# Out:
# 0.9905246158453058

# %%
df_score[['pAN:proxy_0_100_common_common', 'pAN:proxy_0_1000_common_common']]
# Out:
#                pAN:proxy_0_100_common_common  pAN:proxy_0_1000_common_common
# SNP
# 1:66435_ATT_A                       0.059866                        0.146189
# rs555652149                         0.295387                        1.184963
# rs531531651                         0.139579                        0.603959
# rs185487977                         0.340735                        0.599530
# rs548107800                         0.003909                        0.147143
# ...                                      ...                             ...
# rs370652263                        -1.189226                        1.232365
# rs541098394                         0.133695                        0.215772
# rs553081191                         0.026397                        0.196966
# rs149712012                        -0.009371                        0.087071
# rs535432390                         0.207861                        0.461265
#
# [14820648 rows x 2 columns]

# %%
pAN_list
# Out:
# ['pAN:proxy_0_100_common_common',
#  'pAN:proxy_0_100_lf_lf',
#  'pAN:proxy_0_1000_common_common',
#  'pAN:proxy_0_1000_lf_lf',
#  'pAN:proxy_0_10000_common_common',
#  'pAN:proxy_0_10000_lf_lf',
#  'pAN:exon_common_common',
#  'pAN:exon_lf_lf',
#  'pAN:exonic_gene_common_common',
#  'pAN:exonic_gene_lf_lf',
#  'pAN:gene_common_common',
#  'pAN:gene_lf_lf',
#  'pAN:cS2G_promoter_common_common',
#  'pAN:cS2G_promoter_lf_lf',
#  'pAN:protein_domain_common_common',
#  'pAN:protein_domain_lf_lf',
#  'pAN:H3K27ac_Hnisz_0_100_common_common',
#  'pAN:H3K27ac_Hnisz_0_100_lf_lf',
#  'pAN:H3K27ac_PGC2_0_100_common_common',
#  'pAN:H3K27ac_PGC2_0_100_lf_lf',
#  'pAN:H3K4me1_Trynka_0_100_common_common',
#  'pAN:H3K4me1_Trynka_0_100_lf_lf',
#  'pAN:Intron_UCSC_0_100_common_common',
#  'pAN:Intron_UCSC_0_100_lf_lf',
#  'pAN:Repressed_Hoffman_0_100_common_common',
#  'pAN:Repressed_Hoffman_0_100_lf_lf',
#  'pAN:Transcribed_Hoffman_0_100_common_common',
#  'pAN:Transcribed_Hoffman_0_100_lf_lf',
#  'pAN:DGF_ENCODE_0_1000_common_common',
#  'pAN:DGF_ENCODE_0_1000_lf_lf',
#  'pAN:DHS_Trynka_0_1000_common_common',
#  'pAN:DHS_Trynka_0_1000_lf_lf',
#  'pAN:DHS_peaks_Trynka_0_1000_common_common',
#  'pAN:DHS_peaks_Trynka_0_1000_lf_lf',
#  'pAN:Enhancer_Hoffman_0_1000_common_common',
#  'pAN:Enhancer_Hoffman_0_1000_lf_lf',
#  'pAN:FetalDHS_Trynka_0_1000_common_common',
#  'pAN:FetalDHS_Trynka_0_1000_lf_lf',
#  'pAN:H3K27ac_Hnisz_0_1000_common_common',
#  'pAN:H3K27ac_Hnisz_0_1000_lf_lf',
#  'pAN:H3K27ac_PGC2_0_1000_common_common',
#  'pAN:H3K27ac_PGC2_0_1000_lf_lf',
#  'pAN:H3K4me1_Trynka_0_1000_common_common',
#  'pAN:H3K4me1_Trynka_0_1000_lf_lf',
#  'pAN:H3K4me1_peaks_Trynka_0_1000_common_common',
#  'pAN:H3K4me1_peaks_Trynka_0_1000_lf_lf',
#  'pAN:H3K4me3_Trynka_0_1000_common_common',
#  'pAN:H3K4me3_Trynka_0_1000_lf_lf',
#  'pAN:H3K9ac_Trynka_0_1000_common_common',
#  'pAN:H3K9ac_Trynka_0_1000_lf_lf',
#  'pAN:Intron_UCSC_0_1000_common_common',
#  'pAN:Intron_UCSC_0_1000_lf_lf',
#  'pAN:Promoter_UCSC_0_1000_common_common',
#  'pAN:Promoter_UCSC_0_1000_lf_lf',
#  'pAN:Repressed_Hoffman_0_1000_common_common',
#  'pAN:Repressed_Hoffman_0_1000_lf_lf',
#  'pAN:SuperEnhancer_Hnisz_0_1000_common_common',
#  'pAN:SuperEnhancer_Hnisz_0_1000_lf_lf',
#  'pAN:TFBS_ENCODE_0_1000_common_common',
#  'pAN:TFBS_ENCODE_0_1000_lf_lf',
#  'pAN:Transcribed_Hoffman_0_1000_common_common',
#  'pAN:Transcribed_Hoffman_0_1000_lf_lf',
#  'pAN:Vahedi_Tcell_TE_0_1000_common_common',
#  'pAN:Vahedi_Tcell_TE_0_1000_lf_lf',
#  'pAN:proxy_0_100_ld_p0_p100_maf_common_block',
#  'pAN:proxy_0_100_ld_p0_p100_maf_lf_block',
#  'pAN:proxy_0_1000_ld_p0_p100_maf_common_block',
#  'pAN:proxy_0_1000_ld_p0_p100_maf_lf_block',
#  'pAN:proxy_0_10000_ld_p0_p100_maf_common_block',
#  'pAN:proxy_0_10000_ld_p0_p100_maf_lf_block',
#  'pAN:proxy_0_100_ld_n100_p0_maf_common_block',
#  'pAN:proxy_0_100_ld_n100_p0_maf_lf_block',
#  'pAN:proxy_0_1000_ld_n100_p0_maf_common_block',
#  'pAN:proxy_0_1000_ld_n100_p0_maf_lf_block',
#  'pAN:proxy_0_10000_ld_n100_p0_maf_common_block',
#  'pAN:proxy_0_10000_ld_n100_p0_maf_lf_block']
