# %%
import pandas as pd
import numpy as np
import os
import gzip
import time
import seaborn as sns
import matplotlib.pyplot as plt
import ldspec

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
DATA_PATH = "/n/groups/price/martin/LDSPEC_data/UKBimp_337K_MAF001_chimp"
DIC_PANNOT = {   
#     # prox
#     'prox_0_100_common': DATA_PATH + '/pannot_basic/prox_0_100/proxy_0_100.ld_full.maf_common_block.c@.pannot_mat.npz',
#     'prox_0_100_lf': DATA_PATH + '/pannot_basic/prox_0_100/proxy_0_100.ld_full.maf_lf_block.c@.pannot_mat.npz',
#     'prox_0_1000_common': DATA_PATH + '/pannot_basic/prox_0_1000/proxy_0_1000.ld_full.maf_common_block.c@.pannot_mat.npz',
#     'prox_0_1000_lf': DATA_PATH + '/pannot_basic/prox_0_1000/proxy_0_1000.ld_full.maf_lf_block.c@.pannot_mat.npz',
#     'prox_100_1000_common': DATA_PATH + '/pannot_basic/prox_100_1000/proxy_100_1000.ld_full.maf_common_block.c@.pannot_mat.npz',
#     'prox_100_1000_lf': DATA_PATH + '/pannot_basic/prox_100_1000/proxy_100_1000.ld_full.maf_lf_block.c@.pannot_mat.npz',
#     'prox_0_10000_common': DATA_PATH + '/pannot_basic/prox_0_10000/proxy_0_10000.ld_full.maf_common_block.c@.pannot_mat.npz',
#     'prox_0_10000_lf': DATA_PATH + '/pannot_basic/prox_0_10000/proxy_0_10000.ld_full.maf_lf_block.c@.pannot_mat.npz',
#     'prox_1000_10000_common': DATA_PATH + '/pannot_basic/prox_1000_10000/proxy_1000_10000.ld_full.maf_common_block.c@.pannot_mat.npz',
#     'prox_1000_10000_lf': DATA_PATH + '/pannot_basic/prox_1000_10000/proxy_1000_10000.ld_full.maf_lf_block.c@.pannot_mat.npz',
#     # prox, pos-ld
#     'prox_0_100_ld_pos_common': DATA_PATH + '/pannot_basic/prox_0_100_ld_pos/proxy_0_100.ld_p0_p100.maf_common_block.c@.pannot_mat.npz',
#     'prox_0_100_ld_pos_lf': DATA_PATH + '/pannot_basic/prox_0_100_ld_pos/proxy_0_100.ld_p0_p100.maf_lf_block.c@.pannot_mat.npz',
#     'prox_0_1000_ld_pos_common': DATA_PATH + '/pannot_basic/prox_0_1000_ld_pos/proxy_0_1000.ld_p0_p100.maf_common_block.c@.pannot_mat.npz',
#     'prox_0_1000_ld_pos_lf': DATA_PATH + '/pannot_basic/prox_0_1000_ld_pos/proxy_0_1000.ld_p0_p100.maf_lf_block.c@.pannot_mat.npz',
#     'prox_100_1000_ld_pos_common': DATA_PATH + '/pannot_basic/prox_100_1000_ld_pos/proxy_100_1000.ld_p0_p100.maf_common_block.c@.pannot_mat.npz',
#     'prox_100_1000_ld_pos_lf': DATA_PATH + '/pannot_basic/prox_100_1000_ld_pos/proxy_100_1000.ld_p0_p100.maf_lf_block.c@.pannot_mat.npz',
#     'prox_0_10000_ld_pos_common': DATA_PATH + '/pannot_basic/prox_0_10000_ld_pos/proxy_0_10000.ld_p0_p100.maf_common_block.c@.pannot_mat.npz',
#     'prox_0_10000_ld_pos_lf': DATA_PATH + '/pannot_basic/prox_0_10000_ld_pos/proxy_0_10000.ld_p0_p100.maf_lf_block.c@.pannot_mat.npz',
#     'prox_1000_10000_ld_pos_common': DATA_PATH + '/pannot_basic/prox_1000_10000_ld_pos/proxy_1000_10000.ld_p0_p100.maf_common_block.c@.pannot_mat.npz',
#     'prox_1000_10000_ld_pos_lf': DATA_PATH + '/pannot_basic/prox_1000_10000_ld_pos/proxy_1000_10000.ld_p0_p100.maf_lf_block.c@.pannot_mat.npz',
#     # prox, neg-ld
#     'prox_0_100_ld_neg_common': DATA_PATH + '/pannot_basic/prox_0_100_ld_neg/proxy_0_100.ld_n100_p0.maf_common_block.c@.pannot_mat.npz',
#     'prox_0_100_ld_neg_lf': DATA_PATH + '/pannot_basic/prox_0_100_ld_neg/proxy_0_100.ld_n100_p0.maf_lf_block.c@.pannot_mat.npz',
#     'prox_0_1000_ld_neg_common': DATA_PATH + '/pannot_basic/prox_0_1000_ld_neg/proxy_0_1000.ld_n100_p0.maf_common_block.c@.pannot_mat.npz',
#     'prox_0_1000_ld_neg_lf': DATA_PATH + '/pannot_basic/prox_0_1000_ld_neg/proxy_0_1000.ld_n100_p0.maf_lf_block.c@.pannot_mat.npz',
#     'prox_100_1000_ld_neg_common': DATA_PATH + '/pannot_basic/prox_100_1000_ld_neg/proxy_100_1000.ld_n100_p0.maf_common_block.c@.pannot_mat.npz',
#     'prox_100_1000_ld_neg_lf': DATA_PATH + '/pannot_basic/prox_100_1000_ld_neg/proxy_100_1000.ld_n100_p0.maf_lf_block.c@.pannot_mat.npz',
#     'prox_0_10000_ld_neg_common': DATA_PATH + '/pannot_basic/prox_0_10000_ld_neg/proxy_0_10000.ld_n100_p0.maf_common_block.c@.pannot_mat.npz',
#     'prox_0_10000_ld_neg_lf': DATA_PATH + '/pannot_basic/prox_0_10000_ld_neg/proxy_0_10000.ld_n100_p0.maf_lf_block.c@.pannot_mat.npz',
#     'prox_1000_10000_ld_neg_common': DATA_PATH + '/pannot_basic/prox_1000_10000_ld_neg/proxy_1000_10000.ld_n100_p0.maf_common_block.c@.pannot_mat.npz',
#     'prox_1000_10000_ld_neg_lf': DATA_PATH + '/pannot_basic/prox_1000_10000_ld_neg/proxy_1000_10000.ld_n100_p0.maf_lf_block.c@.pannot_mat.npz',
    # prox, pos-high-ld
    'prox_0_100_ld_highpos_common': DATA_PATH + '/pannot_basic/prox_0_100_ld_high_pos/proxy_0_100.ld_p50_p100.maf_common_block.c@.pannot_mat.npz',
    'prox_0_100_ld_highpos_lf': DATA_PATH + '/pannot_basic/prox_0_100_ld_high_pos/proxy_0_100.ld_p50_p100.maf_lf_block.c@.pannot_mat.npz',
    'prox_0_1000_ld_highpos_common': DATA_PATH + '/pannot_basic/prox_0_1000_ld_high_pos/proxy_0_1000.ld_p50_p100.maf_common_block.c@.pannot_mat.npz',
    'prox_0_1000_ld_highpos_lf': DATA_PATH + '/pannot_basic/prox_0_1000_ld_high_pos/proxy_0_1000.ld_p50_p100.maf_lf_block.c@.pannot_mat.npz',
    'prox_100_1000_ld_highpos_common': DATA_PATH + '/pannot_basic/prox_100_1000_ld_high_pos/proxy_100_1000.ld_p50_p100.maf_common_block.c@.pannot_mat.npz',
    'prox_100_1000_ld_highpos_lf': DATA_PATH + '/pannot_basic/prox_100_1000_ld_high_pos/proxy_100_1000.ld_p50_p100.maf_lf_block.c@.pannot_mat.npz',
#     # prox, neg-high-ld
#     'prox_0_100_ld_highneg_common': DATA_PATH + '/pannot_basic/prox_0_100_ld_high_neg/proxy_0_100.ld_n100_n50.maf_common_block.c@.pannot_mat.npz',
#     'prox_0_100_ld_highneg_lf': DATA_PATH + '/pannot_basic/prox_0_100_ld_high_neg/proxy_0_100.ld_n100_n50.maf_lf_block.c@.pannot_mat.npz',
#     'prox_0_1000_ld_highneg_common': DATA_PATH + '/pannot_basic/prox_0_1000_ld_high_neg/proxy_0_1000.ld_n100_n50.maf_common_block.c@.pannot_mat.npz',
#     'prox_0_1000_ld_highneg_lf': DATA_PATH + '/pannot_basic/prox_0_1000_ld_high_neg/proxy_0_1000.ld_n100_n50.maf_lf_block.c@.pannot_mat.npz',
}

for val in DIC_PANNOT.values():
    print(val)
# Out:
# /n/groups/price/martin/LDSPEC_data/UKBimp_337K_MAF001_chimp/pannot_basic/prox_0_100_ld_high_pos/proxy_0_100.ld_p50_p100.maf_common_block.c@.pannot_mat.npz
# /n/groups/price/martin/LDSPEC_data/UKBimp_337K_MAF001_chimp/pannot_basic/prox_0_100_ld_high_pos/proxy_0_100.ld_p50_p100.maf_lf_block.c@.pannot_mat.npz
# /n/groups/price/martin/LDSPEC_data/UKBimp_337K_MAF001_chimp/pannot_basic/prox_0_1000_ld_high_pos/proxy_0_1000.ld_p50_p100.maf_common_block.c@.pannot_mat.npz
# /n/groups/price/martin/LDSPEC_data/UKBimp_337K_MAF001_chimp/pannot_basic/prox_0_1000_ld_high_pos/proxy_0_1000.ld_p50_p100.maf_lf_block.c@.pannot_mat.npz
# /n/groups/price/martin/LDSPEC_data/UKBimp_337K_MAF001_chimp/pannot_basic/prox_100_1000_ld_high_pos/proxy_100_1000.ld_p50_p100.maf_common_block.c@.pannot_mat.npz
# /n/groups/price/martin/LDSPEC_data/UKBimp_337K_MAF001_chimp/pannot_basic/prox_100_1000_ld_high_pos/proxy_100_1000.ld_p50_p100.maf_lf_block.c@.pannot_mat.npz

# %%
# Unfinished files
for pannot in DIC_PANNOT:
    for CHR in range(1,23):
#     for CHR in [22]:
        if os.path.exists(DIC_PANNOT[pannot].replace("@", "%d" % CHR)) is False:
            print(pannot, CHR)

# %%
# List of all pannot files
with open('pannot_list_basic.rv1.txt', 'w') as f:
    for pannot in DIC_PANNOT:
        f.write('%s\n' % DIC_PANNOT[pannot])

# %% [markdown]
# ### Check correctness

# %%
CHR = 22

# PGEN
PGEN_FILE = '/n/scratch/users/j/jz286/imp_geno_chimp/ukb_imp_chr@_v3_chimp'
df_snp_chr = ldspec.util.read_pgen(PGEN_FILE.replace("@", "%d" % CHR))["pvar"]
df_snp_chr["AF"] = ldspec.util.read_pgen(PGEN_FILE.replace("@", "%d" % CHR))["afreq"]["MAF"]
df_snp_chr["MAF"] = [min(x, 1-x) for x in df_snp_chr["AF"]]
df_snp_chr["mbin"] = [ldspec.util.get_mbin(x) for x in df_snp_chr["MAF"]]
df_snp_chr.index = df_snp_chr['SNP']

# LD
mat_ld, dic_range = ldspec.util.read_ld(
    '/n/groups/price/UKBiobank/insample_ld/ld_files/ukb_imp_v3_chimp.c%d_s0_e10000_ld.npz' % CHR
)

# %%
for pAN in DIC_PANNOT:
# for pAN in ['prox_0_100_common', 'prox_0_100_ld_pos_lf']:
    print(pAN)
    print(DIC_PANNOT[pAN])
    mat_G = ldspec.util.read_pannot_mat(DIC_PANNOT[pAN].replace("@", "%d" % CHR))
    print('    mat_G', mat_G.shape, mat_G.getformat(), mat_G.sum())
    
    n_print = 0
    i=0
    while i < 20000:      
        if mat_G.indptr[i]==mat_G.indptr[i+1]:
            i += 1
            continue    
            
        j = mat_G.indices[mat_G.indptr[i]:mat_G.indptr[i+1]][0]
        
        print('    ------------------------------------------------------------------------------')
        print('    MAF = %0.4f, %0.4f,    dist = %d,    LD = %0.4f' % (
            df_snp_chr['MAF'][i], df_snp_chr['MAF'][j], df_snp_chr['BP'][i] - df_snp_chr['BP'][j], 
            mat_ld[i,j] if i<10000 else np.nan
        ))
                    
        i+=10
        n_print+=1
        if n_print>9:
            break
            
    
    print('==================================================================================')
#     break
# Out:
# prox_0_100_ld_highpos_common
# /n/groups/price/martin/LDSPEC_data/UKBimp_337K_MAF001_chimp/pannot_basic/prox_0_100_ld_high_pos/proxy_0_100.ld_p50_p100.maf_common_block.c@.pannot_mat.npz
#     mat_G (199680, 199680) csr 23788
#     ------------------------------------------------------------------------------
#     MAF = 0.0809, 0.0800,    dist = -67,    LD = 0.9758
#     ------------------------------------------------------------------------------
#     MAF = 0.0543, 0.0543,    dist = -81,    LD = 0.8990
#     ------------------------------------------------------------------------------
#     MAF = 0.0530, 0.0538,    dist = -77,    LD = 0.9306
#     ------------------------------------------------------------------------------
#     MAF = 0.0548, 0.0546,    dist = -86,    LD = 0.9864
#     ------------------------------------------------------------------------------
#     MAF = 0.0547, 0.0547,    dist = -1,    LD = 0.9216
# ...

# %% [markdown]
# ### Old code
