# %%
import pandas as pd
import numpy as np
import io
import gdreg

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def read_vcf(path):
    with open(path, 'r') as f:
        lines = [l for l in f if not l.startswith('##')]
    return pd.read_csv(
        io.StringIO(''.join(lines)),
        dtype={'#CHROM': str, 'POS': int, 'ID': str, 'REF': str, 'ALT': str,
               'QUAL': str, 'FILTER': str, 'INFO': str},
        sep='\t'
    ).rename(columns={'#CHROM': 'CHROM'})

def get_info_ann(anno_line):
    for anno in anno_line.split(';'):
        if anno[0:3] == 'ANN':
            annotation_list = [
                x.split('|')[1] for x in anno.split(',') if ('WARNING' not in x) & ('ERROR' not in x )]
            annotation_list = '&'.join(annotation_list)
            annotation_list = set(annotation_list.split('&'))
            return ','.join(annotation_list)
    return ''

# %%
dic_func = {
    "intergenic_region" : ["intergenic_region"],
    "intron_variant" : ["intron_variant"],
    "downstream_gene_variant" : ["downstream_gene_variant"],
    "upstream_gene_variant" : ["upstream_gene_variant"],
    "3_prime_UTR_variant" : ["3_prime_UTR_variant"],
    "5_prime_UTR_variant" : ["5_prime_UTR_variant"],
    "non_coding_transcript_exon_variant" : ["non_coding_transcript_exon_variant"],
    "splice_region_variant" : ["splice_region_variant"],
    # Based on Impact
    'nonsynonymous_variant': [
        # LOF from Backman_Nature_2021
        'stop_gained',
        'stop_lost', 
        'splice_donor_variant',
        'splice_acceptor_variant',
        'start_lost', 
        'frameshift_variant',
        # missense_variant
        "missense_variant", 
        "5_prime_UTR_premature_start_codon_gain_variant",
        "structural_interaction_variant",
        "disruptive_inframe_deletion", 
        "disruptive_inframe_insertion", 
        "conservative_inframe_deletion", 
        "conservative_inframe_insertion", 
    ],
    'synonymous_variant': ["synonymous_variant"],
    
}

# %%
# Read annotation
VCF_FILE = "/n/groups/price/martin/LDSPEC_data/UKBimp_337K_MAF001/baseline_annot/snfeff/ukb_imp_chr@_v3.vcf"
OUT_FILE = "/n/groups/price/martin/LDSPEC_data/UKBimp_337K_MAF001/baseline_annot/snfeff/ukb_imp_chr@_v3.annot.gz"

# ANN_list
ANN_list = []
for temp_list in dic_func.values():
    ANN_list.extend(temp_list)

for CHR in range(1,23):
# for CHR in [21]:
    print("# CHR %d" % CHR)
    df_vcf = read_vcf(VCF_FILE.replace("@", "%d"%CHR))
    df_vcf.index = df_vcf['ID']
    df_vcf = df_vcf[['CHROM', 'ID', 'POS', 'REF', 'ALT', 'INFO', 'FORMAT']]
    
    # Get functional annotation
    df_vcf["INFO_ANN"] = [get_info_ann(x) for x in df_vcf['INFO']]
    for ANN in ANN_list:
        df_vcf[ANN] = [ANN in x.split(",") for x in df_vcf["INFO_ANN"]]
    for term in dic_func:
        df_vcf["AN:snpeff_%s" % term] = df_vcf[dic_func[term]].sum(axis=1).astype(bool)
        
    snpeff_list = [x for x in df_vcf if x.startswith("AN:")]
    df_vcf = df_vcf[["CHROM", "ID", "POS"] + snpeff_list]
    df_vcf.columns = ['CHR', 'SNP', 'BP'] + snpeff_list
    for AN in snpeff_list:
        print("    %s %d" % (AN, df_vcf[AN].sum()))
    gdreg.util.write_annot(df_vcf, OUT_FILE.replace("@", "%d"%CHR))
# Out:
# # CHR 1
#     AN:snpeff_intergenic_region 531593
#     AN:snpeff_intron_variant 596629
#     AN:snpeff_downstream_gene_variant 178411
#     AN:snpeff_upstream_gene_variant 176916
#     AN:snpeff_3_prime_UTR_variant 14813
#     AN:snpeff_5_prime_UTR_variant 3612
#     AN:snpeff_non_coding_transcript_exon_variant 24364
#     AN:snpeff_splice_region_variant 1912
#     AN:snpeff_nonsynonymous_variant 7545
#     AN:snpeff_synonymous_variant 4470
# 'CM' missing from df_annot.columns, add 'CM' column with 0
# # CHR 2
#     AN:snpeff_intergenic_region 570569
#     AN:snpeff_intron_variant 658041
#     AN:snpeff_downstream_gene_variant 150410
#     AN:snpeff_upstream_gene_variant 144003
#     AN:snpeff_3_prime_UTR_variant 10795
#     AN:snpeff_5_prime_UTR_variant 2536
#     AN:snpeff_non_coding_transcript_exon_variant 20306
#     AN:snpeff_splice_region_variant 1358
#     AN:snpeff_nonsynonymous_variant 5036
#     AN:snpeff_synonymous_variant 3198
# 'CM' missing from df_annot.columns, add 'CM' column with 0
# # CHR 3
#     AN:snpeff_intergenic_region 443153
#     AN:snpeff_intron_variant 589894
#     AN:snpeff_downstream_gene_variant 124064
#     AN:snpeff_upstream_gene_variant 118757
#     AN:snpeff_3_prime_UTR_variant 9009
#     AN:snpeff_5_prime_UTR_variant 2399
#     AN:snpeff_non_coding_transcript_exon_variant 16665
#     AN:snpeff_splice_region_variant 1175
#     AN:snpeff_nonsynonymous_variant 4001
#     AN:snpeff_synonymous_variant 2521
# 'CM' missing from df_annot.columns, add 'CM' column with 0
# # CHR 4
#     AN:snpeff_intergenic_region 558065
#     AN:snpeff_intron_variant 495275
#     AN:snpeff_downstream_gene_variant 104166
#     AN:snpeff_upstream_gene_variant 98345
#     AN:snpeff_3_prime_UTR_variant 7205
#     AN:snpeff_5_prime_UTR_variant 1620
#     AN:snpeff_non_coding_transcript_exon_variant 12900
#     AN:snpeff_splice_region_variant 949
#     AN:snpeff_nonsynonymous_variant 2945
#     AN:snpeff_synonymous_variant 1810
# 'CM' missing from df_annot.columns, add 'CM' column with 0
# # CHR 5
#     AN:snpeff_intergenic_region 488486
#     AN:snpeff_intron_variant 454976
#     AN:snpeff_downstream_gene_variant 111535
#     AN:snpeff_upstream_gene_variant 104944
#     AN:snpeff_3_prime_UTR_variant 7819
#     AN:snpeff_5_prime_UTR_variant 1822
#     AN:snpeff_non_coding_transcript_exon_variant 14227
#     AN:snpeff_splice_region_variant 924
#     AN:snpeff_nonsynonymous_variant 3312
#     AN:snpeff_synonymous_variant 2137
# 'CM' missing from df_annot.columns, add 'CM' column with 0
# # CHR 6
#     AN:snpeff_intergenic_region 525056
#     AN:snpeff_intron_variant 424988
#     AN:snpeff_downstream_gene_variant 117103
#     AN:snpeff_upstream_gene_variant 112959
#     AN:snpeff_3_prime_UTR_variant 9419
#     AN:snpeff_5_prime_UTR_variant 2260
#     AN:snpeff_non_coding_transcript_exon_variant 15552
#     AN:snpeff_splice_region_variant 1098
#     AN:snpeff_nonsynonymous_variant 4306
#     AN:snpeff_synonymous_variant 2598
# 'CM' missing from df_annot.columns, add 'CM' column with 0
# # CHR 7
#     AN:snpeff_intergenic_region 381355
#     AN:snpeff_intron_variant 463443
#     AN:snpeff_downstream_gene_variant 107932
#     AN:snpeff_upstream_gene_variant 103673
#     AN:snpeff_3_prime_UTR_variant 7740
#     AN:snpeff_5_prime_UTR_variant 1870
#     AN:snpeff_non_coding_transcript_exon_variant 15358
#     AN:snpeff_splice_region_variant 1070
#     AN:snpeff_nonsynonymous_variant 3610
#     AN:snpeff_synonymous_variant 2264
# 'CM' missing from df_annot.columns, add 'CM' column with 0
# # CHR 8
#     AN:snpeff_intergenic_region 373500
#     AN:snpeff_intron_variant 433011
#     AN:snpeff_downstream_gene_variant 94707
#     AN:snpeff_upstream_gene_variant 90415
#     AN:snpeff_3_prime_UTR_variant 6022
#     AN:snpeff_5_prime_UTR_variant 1628
#     AN:snpeff_non_coding_transcript_exon_variant 12161
#     AN:snpeff_splice_region_variant 815
#     AN:snpeff_nonsynonymous_variant 2541
#     AN:snpeff_synonymous_variant 1582
# 'CM' missing from df_annot.columns, add 'CM' column with 0
# # CHR 9
#     AN:snpeff_intergenic_region 331941
#     AN:snpeff_intron_variant 294893
#     AN:snpeff_downstream_gene_variant 75501
#     AN:snpeff_upstream_gene_variant 75439
#     AN:snpeff_3_prime_UTR_variant 6083
#     AN:snpeff_5_prime_UTR_variant 1641
#     AN:snpeff_non_coding_transcript_exon_variant 9923
#     AN:snpeff_splice_region_variant 716
#     AN:snpeff_nonsynonymous_variant 3092
#     AN:snpeff_synonymous_variant 2009
# 'CM' missing from df_annot.columns, add 'CM' column with 0
# # CHR 10
#     AN:snpeff_intergenic_region 359133
#     AN:snpeff_intron_variant 373405
#     AN:snpeff_downstream_gene_variant 85024
#     AN:snpeff_upstream_gene_variant 82888
#     AN:snpeff_3_prime_UTR_variant 6571
#     AN:snpeff_5_prime_UTR_variant 1402
#     AN:snpeff_non_coding_transcript_exon_variant 10151
#     AN:snpeff_splice_region_variant 852
#     AN:snpeff_nonsynonymous_variant 2923
#     AN:snpeff_synonymous_variant 1853
# 'CM' missing from df_annot.columns, add 'CM' column with 0
# # CHR 11
#     AN:snpeff_intergenic_region 324640
#     AN:snpeff_intron_variant 383677
#     AN:snpeff_downstream_gene_variant 115393
#     AN:snpeff_upstream_gene_variant 115979
#     AN:snpeff_3_prime_UTR_variant 7678
#     AN:snpeff_5_prime_UTR_variant 2606
#     AN:snpeff_non_coding_transcript_exon_variant 16496
#     AN:snpeff_splice_region_variant 1120
#     AN:snpeff_nonsynonymous_variant 5033
#     AN:snpeff_synonymous_variant 2827
# 'CM' missing from df_annot.columns, add 'CM' column with 0
# # CHR 12
#     AN:snpeff_intergenic_region 302469
#     AN:snpeff_intron_variant 378039
#     AN:snpeff_downstream_gene_variant 109375
#     AN:snpeff_upstream_gene_variant 104760
#     AN:snpeff_3_prime_UTR_variant 7979
#     AN:snpeff_5_prime_UTR_variant 2295
#     AN:snpeff_non_coding_transcript_exon_variant 13660
#     AN:snpeff_splice_region_variant 1089
#     AN:snpeff_nonsynonymous_variant 3726
#     AN:snpeff_synonymous_variant 2394
# 'CM' missing from df_annot.columns, add 'CM' column with 0
# # CHR 13
#     AN:snpeff_intergenic_region 327746
#     AN:snpeff_intron_variant 203134
#     AN:snpeff_downstream_gene_variant 46196
#     AN:snpeff_upstream_gene_variant 44288
#     AN:snpeff_3_prime_UTR_variant 2498
#     AN:snpeff_5_prime_UTR_variant 622
#     AN:snpeff_non_coding_transcript_exon_variant 5474
#     AN:snpeff_splice_region_variant 423
#     AN:snpeff_nonsynonymous_variant 1192
#     AN:snpeff_synonymous_variant 733
# 'CM' missing from df_annot.columns, add 'CM' column with 0
# # CHR 14
#     AN:snpeff_intergenic_region 211259
#     AN:snpeff_intron_variant 255580
#     AN:snpeff_downstream_gene_variant 72069
#     AN:snpeff_upstream_gene_variant 69443
#     AN:snpeff_3_prime_UTR_variant 4938
#     AN:snpeff_5_prime_UTR_variant 1541
#     AN:snpeff_non_coding_transcript_exon_variant 9705
#     AN:snpeff_splice_region_variant 669
#     AN:snpeff_nonsynonymous_variant 2417
#     AN:snpeff_synonymous_variant 1428
# 'CM' missing from df_annot.columns, add 'CM' column with 0
# # CHR 15
#     AN:snpeff_intergenic_region 138591
#     AN:snpeff_intron_variant 271471
#     AN:snpeff_downstream_gene_variant 70796
#     AN:snpeff_upstream_gene_variant 69333
#     AN:snpeff_3_prime_UTR_variant 4999
#     AN:snpeff_5_prime_UTR_variant 1208
#     AN:snpeff_non_coding_transcript_exon_variant 10422
#     AN:snpeff_splice_region_variant 769
#     AN:snpeff_nonsynonymous_variant 2436
#     AN:snpeff_synonymous_variant 1453
# 'CM' missing from df_annot.columns, add 'CM' column with 0
# # CHR 16
#     AN:snpeff_intergenic_region 177485
#     AN:snpeff_intron_variant 270179
#     AN:snpeff_downstream_gene_variant 86839
#     AN:snpeff_upstream_gene_variant 85219
#     AN:snpeff_3_prime_UTR_variant 6675
#     AN:snpeff_5_prime_UTR_variant 1817
#     AN:snpeff_non_coding_transcript_exon_variant 14645
#     AN:snpeff_splice_region_variant 991
#     AN:snpeff_nonsynonymous_variant 3585
#     AN:snpeff_synonymous_variant 2330
# 'CM' missing from df_annot.columns, add 'CM' column with 0
# # CHR 17
#     AN:snpeff_intergenic_region 144541
#     AN:snpeff_intron_variant 243185
#     AN:snpeff_downstream_gene_variant 98890
#     AN:snpeff_upstream_gene_variant 99606
#     AN:snpeff_3_prime_UTR_variant 8134
#     AN:snpeff_5_prime_UTR_variant 2301
#     AN:snpeff_non_coding_transcript_exon_variant 16052
#     AN:snpeff_splice_region_variant 1176
#     AN:snpeff_nonsynonymous_variant 4329
#     AN:snpeff_synonymous_variant 2759
# 'CM' missing from df_annot.columns, add 'CM' column with 0
# # CHR 18
#     AN:snpeff_intergenic_region 213028
#     AN:snpeff_intron_variant 201167
#     AN:snpeff_downstream_gene_variant 46469
#     AN:snpeff_upstream_gene_variant 44913
#     AN:snpeff_3_prime_UTR_variant 3021
#     AN:snpeff_5_prime_UTR_variant 734
#     AN:snpeff_non_coding_transcript_exon_variant 6098
#     AN:snpeff_splice_region_variant 340
#     AN:snpeff_nonsynonymous_variant 1200
#     AN:snpeff_synonymous_variant 783
# 'CM' missing from df_annot.columns, add 'CM' column with 0
# # CHR 19
#     AN:snpeff_intergenic_region 115676
#     AN:snpeff_intron_variant 197164
#     AN:snpeff_downstream_gene_variant 112121
#     AN:snpeff_upstream_gene_variant 108121
#     AN:snpeff_3_prime_UTR_variant 9225
#     AN:snpeff_5_prime_UTR_variant 2771
#     AN:snpeff_non_coding_transcript_exon_variant 16342
#     AN:snpeff_splice_region_variant 1369
#     AN:snpeff_nonsynonymous_variant 5909
#     AN:snpeff_synonymous_variant 3931
# 'CM' missing from df_annot.columns, add 'CM' column with 0
# # CHR 20
#     AN:snpeff_intergenic_region 159009
#     AN:snpeff_intron_variant 161811
#     AN:snpeff_downstream_gene_variant 46530
#     AN:snpeff_upstream_gene_variant 46575
#     AN:snpeff_3_prime_UTR_variant 3581
#     AN:snpeff_5_prime_UTR_variant 942
#     AN:snpeff_non_coding_transcript_exon_variant 5665
#     AN:snpeff_splice_region_variant 495
#     AN:snpeff_nonsynonymous_variant 1830
#     AN:snpeff_synonymous_variant 1344
# 'CM' missing from df_annot.columns, add 'CM' column with 0
# # CHR 21
#     AN:snpeff_intergenic_region 93136
#     AN:snpeff_intron_variant 97161
#     AN:snpeff_downstream_gene_variant 29089
#     AN:snpeff_upstream_gene_variant 28102
#     AN:snpeff_3_prime_UTR_variant 2040
#     AN:snpeff_5_prime_UTR_variant 405
#     AN:snpeff_non_coding_transcript_exon_variant 4270
#     AN:snpeff_splice_region_variant 245
#     AN:snpeff_nonsynonymous_variant 906
#     AN:snpeff_synonymous_variant 579
# 'CM' missing from df_annot.columns, add 'CM' column with 0
# # CHR 22
#     AN:snpeff_intergenic_region 72844
#     AN:snpeff_intron_variant 115887
#     AN:snpeff_downstream_gene_variant 45794
#     AN:snpeff_upstream_gene_variant 44574
#     AN:snpeff_3_prime_UTR_variant 4127
#     AN:snpeff_5_prime_UTR_variant 915
#     AN:snpeff_non_coding_transcript_exon_variant 7374
#     AN:snpeff_splice_region_variant 483
#     AN:snpeff_nonsynonymous_variant 1775
#     AN:snpeff_synonymous_variant 1207
# 'CM' missing from df_annot.columns, add 'CM' column with 0
